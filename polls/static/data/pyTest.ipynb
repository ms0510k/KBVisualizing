# %%
import pandas as pd

# %%
outgoing_df = self.kb[self.kb.subject.str.match(current_node)]
            ingoing_df = self.kb[self.kb.object.str.match(current_node)]

# %%
data = pd.read_csv('test_data.nt', sep='\t', names=['s','p','o'])

# %%
data
# Out:
#                                                      s                     p  \
# 0                                athlete_garrett_olson  athleteplaysinleague
# 1                                  athlete_mike_piazza  athleteplaysinleague
# 2                               athlete_jake_westbrook  athleteplaysinleague
# 3                            athlete_taylor_tankersley  athleteplaysinleague
# 4                               athlete_aramis_ramirez  athleteplaysinleague
# 5                                  athlete_steve_blake  athleteplaysinleague
# 6                                  coach_justin_miller  athleteplaysinleague
# 7                                athlete_reggie_nelson  athleteplaysinleague
# 8                                 athlete_joseph_addai  athleteplaysinleague
# 9                               personmexico_cody_ross  athleteplaysinleague
# 10                               athlete_michael_young  athleteplaysinleague
# 11                               athlete_alberto_arias  athleteplaysinleague
# 12                            personmexico_jeff_mathis  athleteplaysinleague
# 13                              athlete_dwayne_jarrett  athleteplaysinleague
# 14                                 athlete_jim_jackson  athleteplaysinleague
# 15                                  athlete_tom_seaver  athleteplaysinleague
# 16                               athlete_brian_vickers  athleteplaysinleague
# 17                              athlete_junichi_tazawa  athleteplaysinleague
# 18                               athlete_chipper_jones  athleteplaysinleague
# 19                                coach_brad_childress  athleteplaysinleague
# 20                                 athlete_tom_glavine  athleteplaysinleague
# 21                               athlete_damion_easley  athleteplaysinleague
# 22                                 coach_jeremy_sowers  athleteplaysinleague
# 23                            athlete_laurence_maroney  athleteplaysinleague
# 24                                 athlete_mark_rogers  athleteplaysinleague
# 25                                athlete_daryll_clark  athleteplaysinleague
# 26                                 athlete_matt_morris  athleteplaysinleague
# 27                                athlete_david_wesley  athleteplaysinleague
# 28                            personmexico_tommie_agee  athleteplaysinleague
# 29                                athlete_rafer_alston  athleteplaysinleague
# ..                                                 ...                   ...
# 470          sportsteam_cleveland_indians_organization     teamplaysinleague
# 471                     sportsteam_sacramento_monarchs     teamplaysinleague
# 472                          sportsteam_boston_celtics     teamplaysinleague
# 473                                 sportsteam_packers     teamplaysinleague
# 474                     sportsteam_st__louis_billikens     teamplaysinleague
# 475                   sportsteam_susquehanna_crusaders     teamplaysinleague
# 476                       sportsteam_dickinson_college     teamplaysinleague
# 477                           sportsteam_lincoln_lions     teamplaysinleague
# 478                          sportsteam_colorado_state     teamplaysinleague
# 479  sportsteam_monterey_institute_of_international...     teamplaysinleague
# 480              sportsteam_northern_michigan_wildcats     teamplaysinleague
# 481              sportsteam_governors_state_university     teamplaysinleague
# 482               sportsteam_le_moyne_college_dolphins     teamplaysinleague
# 483                    sportsteam_weber_state_wildcats     teamplaysinleague
# 484                      sportsteam_st_peters_peacocks     teamplaysinleague
# 485                   sportsteam_san_jose_st__spartans     teamplaysinleague
# 486               sportsteam_air_force_academy_falcons     teamplaysinleague
# 487                       sportsteam_washburn_ichabods     teamplaysinleague
# 488                   sportsteam_clarion_golden_eagles     teamplaysinleague
# 489                         sportsteam_new_york_titans     teamplaysinleague
# 490                    sportsteam_san_diego_st__aztecs     teamplaysinleague
# 491                           sportsteam_seattle_storm     teamplaysinleague
# 492             sportsteam_adelphi_university_panthers     teamplaysinleague
# 493                   sportsteam_bemidji_state_beavers     teamplaysinleague
# 494                                 sportsteam_red_sox     teamplaysinleague
# 495                     sportsteam_savannah_st__tigers     teamplaysinleague
# 496                                sportsteam_steelers     teamplaysinleague
# 497                   sportsteam_michigan_tech_huskies     teamplaysinleague
# 498                       sportsteam_rochester_college     teamplaysinleague
# 499                                 sportsteam_brewers     teamplaysinleague
#
#                               o
# 0              sportsleague_mlb
# 1              sportsleague_mlb
# 2              sportsleague_mlb
# 3              sportsleague_mlb
# 4              sportsleague_mlb
# 5              sportsleague_nba
# 6              sportsleague_nfl
# 7              sportsleague_nfl
# 8              sportsleague_nfl
# 9              sportsleague_mlb
# 10             sportsleague_nhl
# 11             sportsleague_mlb
# 12             sportsleague_mlb
# 13             sportsleague_nfl
# 14             sportsleague_nba
# 15             sportsleague_mlb
# 16          sportsleague_nascar
# 17             sportsleague_mlb
# 18             sportsleague_mlb
# 19             sportsleague_nfl
# 20             sportsleague_mlb
# 21             sportsleague_mlb
# 22             sportsleague_mlb
# 23             sportsleague_nfl
# 24             sportsleague_mlb
# 25             sportsleague_acc
# 26             sportsleague_mlb
# 27             sportsleague_nba
# 28             sportsleague_mlb
# 29             sportsleague_nba
# ..                          ...
# 470            sportsleague_mlb
# 471           sportsleague_wnba
# 472            sportsleague_nba
# 473            sportsleague_nfl
# 474           sportsleague_ncaa
# 475           sportsleague_ncaa
# 476  sportsleague_international
# 477           sportsleague_ncaa
# 478           sportsleague_ncaa
# 479  sportsleague_international
# 480           sportsleague_ncaa
# 481           sportsleague_ncaa
# 482           sportsleague_ncaa
# 483           sportsleague_ncaa
# 484           sportsleague_ncaa
# 485           sportsleague_ncaa
# 486           sportsleague_ncaa
# 487           sportsleague_ncaa
# 488           sportsleague_ncaa
# 489            sportsleague_nfl
# 490           sportsleague_ncaa
# 491           sportsleague_wnba
# 492           sportsleague_ncaa
# 493           sportsleague_ncaa
# 494            sportsleague_mlb
# 495           sportsleague_ncaa
# 496            sportsleague_nfl
# 497           sportsleague_ncaa
# 498           sportsleague_ncaa
# 499            sportsleague_mlb
#
# [500 rows x 3 columns]

# %%
for i in range(len(data)):
    data['s'][i] = data['s'][i].replace(data['s'][i].split('_')[0] + '_', '')
    data['o'][i] = data['o'][i].replace(data['o'][i].split('_')[0] + '_', '')

# %%
data
# Out:
#                                                s                     p  \
# 0                                          olson  athleteplaysinleague
# 1                                    mike_piazza  athleteplaysinleague
# 2                                 jake_westbrook  athleteplaysinleague
# 3                              taylor_tankersley  athleteplaysinleague
# 4                                 aramis_ramirez  athleteplaysinleague
# 5                                    steve_blake  athleteplaysinleague
# 6                                  justin_miller  athleteplaysinleague
# 7                                  reggie_nelson  athleteplaysinleague
# 8                                   joseph_addai  athleteplaysinleague
# 9                                      cody_ross  athleteplaysinleague
# 10                                 michael_young  athleteplaysinleague
# 11                                 alberto_arias  athleteplaysinleague
# 12                                   jeff_mathis  athleteplaysinleague
# 13                                dwayne_jarrett  athleteplaysinleague
# 14                                   jim_jackson  athleteplaysinleague
# 15                                    tom_seaver  athleteplaysinleague
# 16                                 brian_vickers  athleteplaysinleague
# 17                                junichi_tazawa  athleteplaysinleague
# 18                                 chipper_jones  athleteplaysinleague
# 19                                brad_childress  athleteplaysinleague
# 20                                   tom_glavine  athleteplaysinleague
# 21                                 damion_easley  athleteplaysinleague
# 22                                 jeremy_sowers  athleteplaysinleague
# 23                              laurence_maroney  athleteplaysinleague
# 24                                   mark_rogers  athleteplaysinleague
# 25                                  daryll_clark  athleteplaysinleague
# 26                                   matt_morris  athleteplaysinleague
# 27                                  david_wesley  athleteplaysinleague
# 28                                   tommie_agee  athleteplaysinleague
# 29                                  rafer_alston  athleteplaysinleague
# ..                                           ...                   ...
# 470               cleveland_indians_organization     teamplaysinleague
# 471                          sacramento_monarchs     teamplaysinleague
# 472                               boston_celtics     teamplaysinleague
# 473                                      packers     teamplaysinleague
# 474                          st__louis_billikens     teamplaysinleague
# 475                        susquehanna_crusaders     teamplaysinleague
# 476                            dickinson_college     teamplaysinleague
# 477                                lincoln_lions     teamplaysinleague
# 478                               colorado_state     teamplaysinleague
# 479  monterey_institute_of_international_studies     teamplaysinleague
# 480                   northern_michigan_wildcats     teamplaysinleague
# 481                   governors_state_university     teamplaysinleague
# 482                    le_moyne_college_dolphins     teamplaysinleague
# 483                         weber_state_wildcats     teamplaysinleague
# 484                           st_peters_peacocks     teamplaysinleague
# 485                        san_jose_st__spartans     teamplaysinleague
# 486                    air_force_academy_falcons     teamplaysinleague
# 487                            washburn_ichabods     teamplaysinleague
# 488                        clarion_golden_eagles     teamplaysinleague
# 489                              new_york_titans     teamplaysinleague
# 490                         san_diego_st__aztecs     teamplaysinleague
# 491                                seattle_storm     teamplaysinleague
# 492                  adelphi_university_panthers     teamplaysinleague
# 493                        bemidji_state_beavers     teamplaysinleague
# 494                                      red_sox     teamplaysinleague
# 495                          savannah_st__tigers     teamplaysinleague
# 496                                     steelers     teamplaysinleague
# 497                        michigan_tech_huskies     teamplaysinleague
# 498                            rochester_college     teamplaysinleague
# 499                                        olson     teamplaysinleague
#
#                  o
# 0              mlb
# 1              mlb
# 2              mlb
# 3              mlb
# 4              mlb
# 5              nba
# 6              nfl
# 7              nfl
# 8              nfl
# 9              mlb
# 10             nhl
# 11             mlb
# 12             mlb
# 13             nfl
# 14             nba
# 15             mlb
# 16          nascar
# 17             mlb
# 18             mlb
# 19             nfl
# 20             mlb
# 21             mlb
# 22             mlb
# 23             nfl
# 24             mlb
# 25             acc
# 26             mlb
# 27             nba
# 28             mlb
# 29             nba
# ..             ...
# 470            mlb
# 471           wnba
# 472            nba
# 473            nfl
# 474           ncaa
# 475           ncaa
# 476  international
# 477           ncaa
# 478           ncaa
# 479  international
# 480           ncaa
# 481           ncaa
# 482           ncaa
# 483           ncaa
# 484           ncaa
# 485           ncaa
# 486           ncaa
# 487           ncaa
# 488           ncaa
# 489            nfl
# 490           ncaa
# 491           wnba
# 492           ncaa
# 493           ncaa
# 494            mlb
# 495           ncaa
# 496            nfl
# 497           ncaa
# 498           ncaa
# 499            mlb
#
# [500 rows x 3 columns]

# %%
lst_data = data.values.tolist()

# %%
lst_data
# Out:
# [['olson', 'athleteplaysinleague', 'mlb'],
#  ['mike_piazza', 'athleteplaysinleague', 'mlb'],
#  ['jake_westbrook', 'athleteplaysinleague', 'mlb'],
#  ['taylor_tankersley', 'athleteplaysinleague', 'mlb'],
#  ['aramis_ramirez', 'athleteplaysinleague', 'mlb'],
#  ['steve_blake', 'athleteplaysinleague', 'nba'],
#  ['justin_miller', 'athleteplaysinleague', 'nfl'],
#  ['reggie_nelson', 'athleteplaysinleague', 'nfl'],
#  ['joseph_addai', 'athleteplaysinleague', 'nfl'],
#  ['cody_ross', 'athleteplaysinleague', 'mlb'],
#  ['michael_young', 'athleteplaysinleague', 'nhl'],
#  ['alberto_arias', 'athleteplaysinleague', 'mlb'],
#  ['jeff_mathis', 'athleteplaysinleague', 'mlb'],
#  ['dwayne_jarrett', 'athleteplaysinleague', 'nfl'],
#  ['jim_jackson', 'athleteplaysinleague', 'nba'],
#  ['tom_seaver', 'athleteplaysinleague', 'mlb'],
#  ['brian_vickers', 'athleteplaysinleague', 'nascar'],
#  ['junichi_tazawa', 'athleteplaysinleague', 'mlb'],
#  ['chipper_jones', 'athleteplaysinleague', 'mlb'],
#  ['brad_childress', 'athleteplaysinleague', 'nfl'],
#  ['tom_glavine', 'athleteplaysinleague', 'mlb'],
#  ['damion_easley', 'athleteplaysinleague', 'mlb'],
#  ['jeremy_sowers', 'athleteplaysinleague', 'mlb'],
#  ['laurence_maroney', 'athleteplaysinleague', 'nfl'],
#  ['mark_rogers', 'athleteplaysinleague', 'mlb'],
#  ['daryll_clark', 'athleteplaysinleague', 'acc'],
#  ['matt_morris', 'athleteplaysinleague', 'mlb'],
#  ['david_wesley', 'athleteplaysinleague', 'nba'],
#  ['tommie_agee', 'athleteplaysinleague', 'mlb'],
#  ['rafer_alston', 'athleteplaysinleague', 'nba'],
#  ['chad_qualls', 'athleteplaysinleague', 'mlb'],
#  ['mike_myers', 'athleteplaysinleague', 'mlb'],
#  ['carl_pavano', 'athleteplaysinleague', 'mlb'],
#  ['chris_young', 'athleteplaysinleague', 'mlb'],
#  ['cj_miles', 'athleteplaysinleague', 'nba'],
#  ['carlos_g_mez', 'athleteplaysinleague', 'mlb'],
#  ['joey_votto', 'athleteplaysinleague', 'mlb'],
#  ['kelly_johnson', 'athleteplaysinleague', 'mlb'],
#  ['jeff_bennett', 'athleteplaysinleague', 'mlb'],
#  ['terrell_owens', 'athleteplaysinleague', 'nfl'],
#  ['jorge_garbajosa', 'athleteplaysinleague', 'nba'],
#  ['mark_martin', 'athleteplaysinleague', 'nascar'],
#  ['dwayne_roloson', 'athleteplaysinleague', 'nhl'],
#  ['david_pauley', 'athleteplaysinleague', 'mlb'],
#  ['justin_tuck', 'athleteplaysinleague', 'nfl'],
#  ['david_west', 'athleteplaysinleague', 'nba'],
#  ['zdeno_chara', 'athleteplaysinleague', 'nhl'],
#  ['buster_posey', 'athleteplaysinleague', 'mlb'],
#  ['andres_nocioni', 'athleteplaysinleague', 'nba'],
#  ['antawn_jamison', 'athleteplaysinleague', 'nba'],
#  ['doc_rivers', 'athletehomestadium', 'td_garden'],
#  ['valtteri_filppula', 'athletehomestadium', 'joe_louis_arena'],
#  ['joe_jurevicius', 'athletehomestadium', 'cleveland_browns_stadium'],
#  ['luke_mccown', 'athletehomestadium', 'pete_times_forum'],
#  ['lance_briggs', 'athletehomestadium', 'soldier_field'],
#  ['raymar_morgan', 'athletehomestadium', 'spartan_stadium'],
#  ['dennis_green', 'athletehomestadium', 'metrodome'],
#  ['tommy_maddox', 'athletehomestadium', 'heinz_field'],
#  ['marvin_williams', 'athletehomestadium', 'philips_arena'],
#  ['ryan_rowland_smith', 'athletehomestadium', 'safeco_field'],
#  ['robert_horry', 'athletehomestadium', 'toyota_center'],
#  ['eric_staal', 'athletehomestadium', 'bank_atlantic_center'],
#  ['brendan_shanahan', 'athletehomestadium', 'prudential_center_2'],
#  ['jose_lopez', 'athletehomestadium', 'safeco_field'],
#  ['mickey_mantle', 'athletehomestadium', 'yankee_stadium'],
#  ['john_barnes', 'athletehomestadium', 'anfield'],
#  ['brandon_jacobs', 'athletehomestadium', 'giants_stadium'],
#  ['laveranues_coles', 'athletehomestadium', 'giants_stadium'],
#  ['chris_perez', 'athletehomestadium', 'giants_stadium'],
#  ['bosh', 'athletehomestadium', 'air_canada_center'],
#  ['jerry_owens', 'athletehomestadium', 'us_cellular_field'],
#  ['dan_carcillo', 'athletehomestadium', 'wrigley_field'],
#  ['sprewell', 'athletehomestadium', 'united_center'],
#  ['jason_marquis', 'athletehomestadium', 'wrigley_field'],
#  ['rene_bourque', 'athletehomestadium', 'wrigley_field'],
#  ['junichi_tazawa', 'athletehomestadium', 'fenway_park'],
#  ['shawn_green', 'athletehomestadium', 'shea_stadium'],
#  ['nnamdi_asomugha', 'athletehomestadium', 'mcafee_coliseum'],
#  ['michael_doleac', 'athletehomestadium', 'amway_arena'],
#  ['scott_thorman', 'athletehomestadium', 'turner_field'],
#  ['scott_olsen', 'athletehomestadium', 'dolphin_stadium'],
#  ['charlie_frye', 'athletehomestadium', 'cleveland_browns_stadium'],
#  ['mike_ditka', 'athletehomestadium', 'soldier_field'],
#  ['thierry_henry', 'athletehomestadium', 'camp_nou'],
#  ['doug_davis', 'athletehomestadium', 'gillette_stadium'],
#  ['derrick_brooks', 'athletehomestadium', 'pete_times_forum'],
#  ['steve_montador', 'athletehomestadium', 'wrigley_field'],
#  ['drew_doughty', 'athletehomestadium', 'staples_center'],
#  ['robbie_fowler', 'athletehomestadium', 'anfield'],
#  ['jed_lowrie', 'athletehomestadium', 'fenway'],
#  ['brian_leetch', 'athletehomestadium', 'giants_stadium'],
#  ['scott_kazmir', 'athletehomestadium', 'pete_times_forum'],
#  ['lebron_james', 'athletehomestadium', 'quicken_loans_arena'],
#  ['chris_volstad', 'athletehomestadium', 'dolphin_stadium'],
#  ['brendan_harris', 'athletehomestadium', 'yankee_stadium'],
#  ['brian_rafalski', 'athletehomestadium', 'joe_louis_arena'],
#  ['damon', 'athletehomestadium', 'arrowhead_stadium'],
#  ['luther_head', 'athletehomestadium', 'toyota_center'],
#  ['jaromir_jagr', 'athletehomestadium', 'giants_stadium'],
#  ['david_clarkson', 'athletehomestadium', 'prudential_center_2'],
#  ['randy_shannon', 'worksfor', 'um'],
#  ['joe_novak', 'worksfor', 'niu'],
#  ['david_roberts', 'worksfor', 'grist'],
#  ['michael_nutter', 'worksfor', 'philadelphia'],
#  ['mike_vaccaro', 'worksfor', 'new_york_post'],
#  ['steve_lopez', 'worksfor', 'los_angeles_times'],
#  ['james_reston', 'worksfor', 'times'],
#  ['patrick_byrne', 'worksfor', 'overstock'],
#  ['ryan_whitney', 'worksfor', 'experts'],
#  ['silvio_berlusconi', 'worksfor', 'italian'],
#  ['andy_reid', 'worksfor', 'philadelphia_eagles'],
#  ['anita_campbell', 'worksfor', 'small_business_trends'],
#  ['jim_boeheim', 'worksfor', 'syracuse'],
#  ['jacques_steinberg', 'worksfor', 'new_york_times'],
#  ['charlie_gibson', 'worksfor', 'abc'],
#  ['john003', 'worksfor', 'new_york_times'],
#  ['mike_lupica', 'worksfor', 'new_york_daily_news'],
#  ['jobs', 'worksfor', 'pixar'],
#  ['glenn_a__britt', 'worksfor', 'time_warner'],
#  ['aubrey_sarvis', 'worksfor', 'sldn'],
#  ['david_shuster', 'worksfor', 'msnbc'],
#  ['richard001', 'worksfor', 'virgin_records'],
#  ['ryan_whitney', 'worksfor', 'plans'],
#  ['kevin_reilly', 'worksfor', 'fox'],
#  ['doc_rivers', 'worksfor', 'boston_celtics'],
#  ['disney', 'worksfor', 'toy'],
#  ['anthony_lewis', 'worksfor', 'times'],
#  ['reggie_herring', 'worksfor', 'arkansas'],
#  ['reggie_theus', 'worksfor', 'new_mexico_state'],
#  ['ed_orgeron', 'worksfor', 'ole_miss'],
#  ['gary_crowton', 'worksfor', 'byu'],
#  ['jeff_zrebiec', 'worksfor', 'baltimore_sun'],
#  ['mike_sherman', 'worksfor', 'packers'],
#  ['bill_kristol', 'worksfor', 'fox'],
#  ['john_marks', 'worksfor', 'tallahassee'],
#  ['john_shea', 'worksfor', 'the_san_francisco_chronicle'],
#  ['lanni', 'worksfor', 'mgm_mirage'],
#  ['stephen', 'worksfor', 'apple002'],
#  ['frank_mcguire', 'worksfor', 'carolina'],
#  ['dick_brown', 'worksfor', 'eds'],
#  ['perenchio', 'worksfor', 'univision'],
#  ['kenneth_lay', 'worksfor', 'enron_and_worldcom'],
#  ['david_brooks', 'worksfor', 'new_york_times'],
#  ['howard_cosell', 'worksfor', 'sports'],
#  ['sven_goran_eriksson', 'worksfor', 'england'],
#  ['cam_cameron', 'worksfor', 'miami'],
#  ['bethany_mclean', 'worksfor', 'fortune001'],
#  ['john_johnson', 'worksfor', 'fannie_mae_and_freddy_mac'],
#  ['ron_fournier', 'worksfor', 'ap'],
#  ['gary_barnett', 'worksfor', 'colorado'],
#  ['san_diego', 'organizationhiredperson', 'norv_turner'],
#  ['associated_press', 'organizationhiredperson', 'ryan_whitney'],
#  ['word', 'organizationhiredperson', 'ryan_whitney'],
#  ['alabama', 'organizationhiredperson', 'price'],
#  ['jacksonville', 'organizationhiredperson', 'jack_del_rio'],
#  ['perot_systems', 'organizationhiredperson', 'peter_altabef'],
#  ['arkansas', 'organizationhiredperson', 'frank_broyles'],
#  ['arizona', 'organizationhiredperson', 'kevin_o_neill'],
#  ['fed', 'organizationhiredperson', 'ryan_whitney'],
#  ['experts', 'organizationhiredperson', 'ryan_whitney'],
#  ['contact', 'organizationhiredperson', 'ryan_whitney'],
#  ['ole_miss', 'organizationhiredperson', 'andy_kennedy'],
#  ['new_york', 'organizationhiredperson', 'mangini'],
#  ['indiana_university', 'organizationhiredperson', 'mike_davis'],
#  ['cavium_networks', 'organizationhiredperson', 'syed_b__ali'],
#  ['detroit', 'organizationhiredperson', 'marinelli'],
#  ['oakland_raiders', 'organizationhiredperson', 'tom_cable'],
#  ['dominion_resources', 'organizationhiredperson', 'thomas_f__farrell_ii'],
#  ['uk', 'organizationhiredperson', 'tubby_smith'],
#  ['arkansas', 'organizationhiredperson', 'bobby_petrino'],
#  ['capitals', 'organizationhiredperson', 'ovechkin'],
#  ['mission', 'organizationhiredperson', 'ryan_whitney'],
#  ['bengals', 'organizationhiredperson', 'marvin_lewis'],
#  ['kentucky', 'organizationhiredperson', 'billy_gillespie'],
#  ['release', 'organizationhiredperson', 'ryan_whitney'],
#  ['powell', 'organizationhiredperson', 'ryan_whitney'],
#  ['united_states', 'organizationhiredperson', 'ryan_whitney'],
#  ['new', 'organizationhiredperson', 'jim_haslett'],
#  ['georgetown', 'organizationhiredperson', 'john_thompson'],
#  ['new_york', 'organizationhiredperson', 'van_gundy'],
#  ['west_virginia', 'organizationhiredperson', 'stewart'],
#  ['micron_technology', 'organizationhiredperson', 'steven_appleton'],
#  ['windstream_corporation', 'organizationhiredperson', 'jeffery_gardner'],
#  ['death_row', 'organizationhiredperson', 'suge_knight'],
#  ['funds', 'organizationhiredperson', 'ryan_whitney'],
#  ['minnesota_vikings', 'organizationhiredperson', 'brad_childress'],
#  ['message', 'organizationhiredperson', 'ryan_whitney'],
#  ['new_mexico', 'organizationhiredperson', 'rocky_long'],
#  ['tampa_bay_lightning', 'organizationhiredperson', 'barry_melrose'],
#  ['harvard_divinity_school', 'organizationhiredperson', 'tim_murphy'],
#  ['lsu', 'organizationhiredperson', 'skip_bertman'],
#  ['new_york', 'organizationhiredperson', 'rudy_guiliani'],
#  ['stax', 'organizationhiredperson', 'jim_stewart'],
#  ['miami', 'organizationhiredperson', 'larry_coker'],
#  ['buffalo_bills', 'organizationhiredperson', 'jauron'],
#  ['policy', 'organizationhiredperson', 'ryan_whitney'],
#  ['clemson', 'organizationhiredperson', 'tommy_bowden'],
#  ['bc', 'organizationhiredperson', 'jeff_jagodzinski'],
#  ['cal', 'organizationhiredperson', 'holmoe'],
#  ['arizona', 'organizationhiredperson', 'lute_olson'],
#  ['jonathon_niese', 'athleteplayssport', 'baseball'],
#  ['antonio_perez', 'athleteplayssport', 'baseball'],
#  ['ryan_gomes', 'athleteplayssport', 'baseball'],
#  ['rick_vandenhurk', 'athleteplayssport', 'baseball'],
#  ['sean_taylor', 'athleteplayssport', 'football'],
#  ['jose_luis_castillo', 'athleteplayssport', 'boxing'],
#  ['darren_oliver', 'athleteplayssport', 'baseball'],
#  ['blaine_neal', 'athleteplayssport', 'baseball'],
#  ['eric_hinske', 'athleteplayssport', 'baseball'],
#  ['dan_runzler', 'athleteplayssport', 'baseball'],
#  ['armando_benitez', 'athleteplayssport', 'baseball'],
#  ['matt_desalvo', 'athleteplayssport', 'baseball'],
#  ['dwyane_wade', 'athleteplayssport', 'basketball'],
#  ['warren_sapp', 'athleteplayssport', 'football'],
#  ['dan_meyer', 'athleteplayssport', 'baseball'],
#  ['angel_sanchez', 'athleteplayssport', 'baseball'],
#  ['franklin_morales', 'athleteplayssport', 'baseball'],
#  ['matt_morris', 'athleteplayssport', 'baseball'],
#  ['masa_kobayashi', 'athleteplayssport', 'baseball'],
#  ['gordon_lewis', 'athleteplayssport', 'golf'],
#  ['kevin_cash', 'athleteplayssport', 'baseball'],
#  ['casey_janssen', 'athleteplayssport', 'baseball'],
#  ['jorge_vasquez', 'athleteplayssport', 'baseball'],
#  ['corky_miller', 'athleteplayssport', 'baseball'],
#  ['brett_wallace', 'athleteplayssport', 'football'],
#  ['brad_bergesen', 'athleteplayssport', 'baseball'],
#  ['roman_colon', 'athleteplayssport', 'baseball'],
#  ['anthony_morrow', 'athleteplayssport', 'basketball'],
#  ['greg_maddux', 'athleteplayssport', 'baseball'],
#  ['aaron_laffey', 'athleteplayssport', 'baseball'],
#  ['the_rock', 'athleteplayssport', 'wrestling'],
#  ['carlos_beltran', 'athleteplayssport', 'baseball'],
#  ['torry_holt', 'athleteplayssport', 'football'],
#  ['bill_hall', 'athleteplayssport', 'baseball'],
#  ['burke_badenhop', 'athleteplayssport', 'baseball'],
#  ['keiichi_yabu', 'athleteplayssport', 'baseball'],
#  ['kevin_youkilis', 'athleteplayssport', 'baseball'],
#  ['john_rheinecker', 'athleteplayssport', 'baseball'],
#  ['chris_burke', 'athleteplayssport', 'hockey'],
#  ['george_brett', 'athleteplayssport', 'baseball'],
#  ['rafer_johnson', 'athleteplayssport', 'track_and_field'],
#  ['roger_mason', 'athleteplayssport', 'basketball'],
#  ['mark_grace', 'athleteplayssport', 'baseball'],
#  ['jose_lima', 'athleteplayssport', 'baseball'],
#  ['josh_fogg', 'athleteplayssport', 'baseball'],
#  ['paul_hornung', 'athleteplayssport', 'football'],
#  ['zaun', 'athleteplayssport', 'baseball'],
#  ['ray_allen', 'athleteplayssport', 'basketball'],
#  ['jeff_hardy', 'athleteplayssport', 'wrestling'],
#  ['randy_winn', 'athleteplayssport', 'football'],
#  ['east_carolina', 'teamplayssport', 'basketball'],
#  ['brewers', 'teamplayssport', 'baseball'],
#  ['golden_bears', 'teamplayssport', 'basketball'],
#  ['oakland_athletics', 'teamplayssport', 'baseball'],
#  ['cleveland_indians_organization', 'teamplayssport', 'baseball'],
#  ['florida_state_university', 'teamplayssport', 'football'],
#  ['germany', 'teamplayssport', 'golf'],
#  ['uc_irvine', 'teamplayssport', 'basketball'],
#  ['milwaukee_bucks', 'teamplayssport', 'basketball'],
#  ['royals', 'teamplayssport', 'hockey'],
#  ['niners', 'teamplayssport', 'hockey'],
#  ['towson_university', 'teamplayssport', 'football'],
#  ['bears_29_17', 'teamplayssport', 'football'],
#  ['edmonton_oilers', 'teamplayssport', 'hockey'],
#  ['new_mexico_state_university', 'teamplayssport', 'basketball'],
#  ['colorado_rockies', 'teamplayssport', 'baseball'],
#  ['harvard_divinity_school', 'teamplayssport', 'football'],
#  ['orlando_magic', 'teamplayssport', 'basketball'],
#  ['nc_state', 'teamplayssport', 'football'],
#  ['montana_state_university', 'teamplayssport', 'basketball'],
#  ['st__louis_cardinals', 'teamplayssport', 'baseball'],
#  ['brown_university', 'teamplayssport', 'basketball'],
#  ['university_of_tennessee', 'teamplayssport', 'basketball'],
#  ['st___louis_browns', 'teamplayssport', 'baseball'],
#  ['italy', 'teamplayssport', 'golf'],
#  ['florida_marlins', 'teamplayssport', 'baseball'],
#  ['ucla', 'teamplayssport', 'softball'],
#  ['minnesota_timberwolves', 'teamplayssport', 'basketball'],
#  ['lsu', 'teamplayssport', 'golf'],
#  ['rangers', 'teamplayssport', 'hockey'],
#  ['mariners', 'teamplayssport', 'baseball'],
#  ['boston_celtics', 'teamplayssport', 'basketball'],
#  ['razorbacks', 'teamplayssport', 'golf'],
#  ['philadelphia_phillies', 'teamplayssport', 'baseball'],
#  ['sonics', 'teamplayssport', 'basketball'],
#  ['philadelphia_warriors', 'teamplayssport', 'basketball'],
#  ['furman_university', 'teamplayssport', 'basketball'],
#  ['wake_forest_university', 'teamplayssport', 'football'],
#  ['ball_state_university', 'teamplayssport', 'football'],
#  ['oregon_state_beavers', 'teamplayssport', 'football'],
#  ['liverpool', 'teamplayssport', 'football'],
#  ['capitals', 'teamplayssport', 'hockey'],
#  ['kentucky_wildcats', 'teamplayssport', 'golf'],
#  ['st___louis_hawks', 'teamplayssport', 'basketball'],
#  ['buccaneers', 'teamplayssport', 'football'],
#  ['chicago_blackhawks', 'teamplayssport', 'hockey'],
#  ['huskers', 'teamplayssport', 'football'],
#  ['astros', 'teamplayssport', 'baseball'],
#  ['miami_dolphins', 'teamplayssport', 'football'],
#  ['oilers', 'teamplayssport', 'hockey'],
#  ['barton', 'personborninlocation', 'york'],
#  ['buddy', 'personborninlocation', 'york'],
#  ['ann', 'personborninlocation', 'york_city'],
#  ['mimi', 'personborninlocation', 'york_city'],
#  ['tom', 'personborninlocation', 'york_city'],
#  ['marcel_duchamp', 'personborninlocation', 'york'],
#  ['caroline002', 'personborninlocation', 'york'],
#  ['alexander001', 'personborninlocation', 'york'],
#  ['clark', 'personborninlocation', 'orleans'],
#  ['larry001', 'personborninlocation', 'york'],
#  ['kevin', 'personborninlocation', 'york'],
#  ['john001', 'personborninlocation', 'york_city'],
#  ['rob', 'personborninlocation', 'york_city'],
#  ['dad', 'personborninlocation', 'york'],
#  ['samuel001', 'personborninlocation', 'york'],
#  ['jobs', 'personborninlocation', 'york'],
#  ['lynch', 'personborninlocation', 'york'],
#  ['queen', 'personborninlocation', 'bathroom'],
#  ['gilbert', 'personborninlocation', 'jamaica'],
#  ['abbas', 'personborninlocation', 'york'],
#  ['lawrence001', 'personborninlocation', 'york_city'],
#  ['jen', 'personborninlocation', 'york'],
#  ['hughes', 'personborninlocation', 'york'],
#  ['andrew', 'personborninlocation', 'york_city'],
#  ['father', 'personborninlocation', 'york'],
#  ['russo', 'personborninlocation', 'york'],
#  ['twins', 'personborninlocation', 'york'],
#  ['wilma', 'personborninlocation', 'cancun'],
#  ['kathleen', 'personborninlocation', 'york'],
#  ['campbell', 'personborninlocation', 'york'],
#  ['grant001', 'personborninlocation', 'york_city'],
#  ['christopher001', 'personborninlocation', 'york_city'],
#  ['adams001', 'personborninlocation', 'york'],
#  ['sienna', 'personborninlocation', 'york'],
#  ['ron', 'personborninlocation', 'york_city'],
#  ['finn', 'personborninlocation', 'york'],
#  ['kyle', 'personborninlocation', 'york'],
#  ['phoebe', 'personborninlocation', 'york'],
#  ['webster', 'personborninlocation', 'york'],
#  ['richard', 'personborninlocation', 'york_city'],
#  ['master001', 'personborninlocation', 'bathroom'],
#  ['solomon', 'personborninlocation', 'york'],
#  ['carrie', 'personborninlocation', 'york'],
#  ['larsen', 'personborninlocation', 'york'],
#  ['jerome', 'personborninlocation', 'york'],
#  ['wright', 'personborninlocation', 'york'],
#  ['celeste', 'personborninlocation', 'york'],
#  ['deborah', 'personborninlocation', 'york'],
#  ['manning', 'personborninlocation', 'york'],
#  ['mom', 'personborninlocation', 'york'],
#  ['facebook', 'organizationheadquarteredincity', 'palo_alto'],
#  ['kwmu', 'organizationheadquarteredincity', 'st_louis'],
#  ['kttv', 'organizationheadquarteredincity', 'los_angeles_county'],
#  ['imf', 'organizationheadquarteredincity', 'washington_d_c'],
#  ['kisw', 'organizationheadquarteredincity', 'seattle'],
#  ['kvea', 'organizationheadquarteredincity', 'los_angeles_county'],
#  ['wsbtv', 'organizationheadquarteredincity', 'atlanta'],
#  ['bloomberg_news', 'organizationheadquarteredincity', 'new_york'],
#  ['wsb_tv', 'organizationheadquarteredincity', 'atlanta'],
#  ['kdhx', 'organizationheadquarteredincity', 'st_louis'],
#  ['krbd', 'organizationheadquarteredincity', 'ketchikan'],
#  ['kola', 'organizationheadquarteredincity', 'redlands'],
#  ['airtran_airways', 'organizationheadquarteredincity', 'atlanta'],
#  ['the_new_yorker', 'organizationheadquarteredincity', 'new_york'],
#  ['american', 'organizationheadquarteredincity', 'miami'],
#  ['wthr_tv', 'organizationheadquarteredincity', 'indianapolis'],
#  ['new_york_post', 'organizationheadquarteredincity', 'new_york'],
#  ['ntt_docomo_inc_', 'organizationheadquarteredincity', 'tokyo'],
#  ['kfsn', 'organizationheadquarteredincity', 'fresno'],
#  ['epa', 'organizationheadquarteredincity', 'washington_d_c'],
#  ['publishers_weekly', 'organizationheadquarteredincity', 'new_york'],
#  ['wjz', 'organizationheadquarteredincity', 'baltimore'],
#  ['ktuu', 'organizationheadquarteredincity', 'anchorage'],
#  ['rolling_stone_magazine', 'organizationheadquarteredincity', 'new_york'],
#  ['knbr', 'organizationheadquarteredincity', 'san_francisco'],
#  ['good_housekeeping', 'organizationheadquarteredincity', 'new_york'],
#  ['reebok', 'organizationheadquarteredincity', 'canton'],
#  ['burger_king_hldgs', 'organizationheadquarteredincity', 'miami'],
#  ['sprint', 'organizationheadquarteredincity', 'kansas_city'],
#  ['kdur', 'organizationheadquarteredincity', 'durango'],
#  ['hilton_hotels', 'organizationheadquarteredincity', 'melbourne'],
#  ['waga', 'organizationheadquarteredincity', 'atlanta'],
#  ['audubon', 'organizationheadquarteredincity', 'new_orleans'],
#  ['wivb', 'organizationheadquarteredincity', 'buffalo'],
#  ['kmph_tv', 'organizationheadquarteredincity', 'fresno'],
#  ['kcsn', 'organizationheadquarteredincity', 'northridge'],
#  ['espn_the_magazine', 'organizationheadquarteredincity', 'new_york'],
#  ['johnson', 'organizationheadquarteredincity', 'new_brunswick'],
#  ['kkbt', 'organizationheadquarteredincity', 'los_angeles_county'],
#  ['sunday_express', 'organizationheadquarteredincity', 'johannesburg'],
#  ['ibm_almaden', 'organizationheadquarteredincity', 'san_jose'],
#  ['customs', 'organizationheadquarteredincity', 'washington_d_c'],
#  ['wsm', 'organizationheadquarteredincity', 'nashville'],
#  ['kusc', 'organizationheadquarteredincity', 'los_angeles_county'],
#  ['keye', 'organizationheadquarteredincity', 'austin'],
#  ['carnival_cruises', 'organizationheadquarteredincity', 'miami'],
#  ['koat', 'organizationheadquarteredincity', 'albuquerque'],
#  ['new_york_observer', 'organizationheadquarteredincity', 'new_york'],
#  ['the_new_york_observer', 'organizationheadquarteredincity', 'new_york'],
#  ['wreg_tv', 'organizationheadquarteredincity', 'memphis'],
#  ['mike_piazza', 'athleteplaysforteam', 'new_york_mets'],
#  ['renaldo_balkman', 'athleteplaysforteam', 'nuggets'],
#  ['casey_blake', 'athleteplaysforteam', 'dodgers'],
#  ['rich_aurilia', 'athleteplaysforteam', 'new_york_giants'],
#  ['andrew_ladd', 'athleteplaysforteam', 'blackhawks'],
#  ['lionel_messi', 'athleteplaysforteam', 'barcelona'],
#  ['dwayne_wade', 'athleteplaysforteam', 'heat'],
#  ['john_terry', 'athleteplaysforteam', 'chelsea'],
#  ['a_j__hawk', 'athleteplaysforteam', 'white_sox'],
#  ['ramon_sessions', 'athleteplaysforteam', 'bucks'],
#  ['john_david_booty', 'athleteplaysforteam', 'usc'],
#  ['adam_loewen', 'athleteplaysforteam', 'orioles'],
#  ['gasol', 'athleteplaysforteam', 'los_angeles_lakers'],
#  ['kris_benson', 'athleteplaysforteam', 'orioles'],
#  ['tim_gleason', 'athleteplaysforteam', 'carolina'],
#  ['chauncey_billups', 'athleteplaysforteam', 'pistons'],
#  ['kevin_mchale', 'athleteplaysforteam', 'boston_celtics'],
#  ['chad_johnson', 'athleteplaysforteam', 'bengals'],
#  ['ron_villone', 'athleteplaysforteam', 'new_york_mets'],
#  ['ryan_fitzpatrick', 'athleteplaysforteam', 'bengals'],
#  ['alexei_ramirez', 'athleteplaysforteam', 'white_sox'],
#  ['ryan_theriot', 'athleteplaysforteam', 'chicago_cubs'],
#  ['andrei_kirilenko', 'athleteplaysforteam', 'utah_jazz'],
#  ['felix_pie', 'athleteplaysforteam', 'chicago_cubs'],
#  ['jay_feely', 'athleteplaysforteam', 'new_york_jets'],
#  ['andrei_markov', 'athleteplaysforteam', 'habs'],
#  ['lorenzen_wright', 'athleteplaysforteam', 'reds'],
#  ['matt_harpring', 'athleteplaysforteam', 'utah_jazz'],
#  ['mookie_wilson', 'athleteplaysforteam', 'new_york_mets'],
#  ['plaxico', 'athleteplaysforteam', 'new_york_giants'],
#  ['kenji_johjima', 'athleteplaysforteam', 'mariners'],
#  ['wade_boggs', 'athleteplaysforteam', 'yankees'],
#  ['mike_green', 'athleteplaysforteam', 'capitals'],
#  ['ruslan_fedotenko', 'athleteplaysforteam', 'new_york_islanders'],
#  ['shawne_merriman', 'athleteplaysforteam', 'sd_chargers'],
#  ['david_carr', 'athleteplaysforteam', 'texans'],
#  ['arjen_robben', 'athleteplaysforteam', 'real_madrid'],
#  ['ilya_kovalchuk', 'athleteplaysforteam', 'atlanta_thrashers'],
#  ['tony_clark', 'athleteplaysforteam', 'arizona_diamond_backs'],
#  ['brodeur', 'athleteplaysforteam', 'devils'],
#  ['smoltz', 'athleteplaysforteam', 'red_sox'],
#  ['chris_snyder', 'athleteplaysforteam', 'arizona_diamond_backs'],
#  ['jason_giambi', 'athleteplaysforteam', 'yankees'],
#  ['niklas_hagman', 'athleteplaysforteam', 'maple_leafs'],
#  ['ian_kinsler', 'athleteplaysforteam', 'rangers'],
#  ['lendale_white', 'athleteplaysforteam', 'titans'],
#  ['griffey', 'athleteplaysforteam', 'reds'],
#  ['teixeira', 'athleteplaysforteam', 'red_sox'],
#  ['brendan_morrison', 'athleteplaysforteam', 'canucks'],
#  ['darren_collison', 'athleteplaysforteam', 'ucla'],
#  ['aalborg_university', 'teamplaysinleague', 'international'],
#  ['the_pennsylvania_state_university', 'teamplaysinleague', 'international'],
#  ['wisconsin_parkside_rangers', 'teamplaysinleague', 'ncaa'],
#  ['parsons_school_of_design', 'teamplaysinleague', 'ncaa'],
#  ['cal_state_monterey_bay_otters', 'teamplaysinleague', 'ncaa'],
#  ['arkansas_tech_wonder_boys', 'teamplaysinleague', 'ncaa'],
#  ['indiana_university', 'teamplaysinleague', 'international'],
#  ['los_angeles_galaxy', 'teamplaysinleague', 'mls'],
#  ['duke_blue_devils', 'teamplaysinleague', 'ncaa'],
#  ['big_12_conference', 'teamplaysinleague', 'ncaa'],
#  ['hofstra_pride', 'teamplaysinleague', 'ncaa'],
#  ['colorado_golden_buffaloes', 'teamplaysinleague', 'ncaa'],
#  ['mariners', 'teamplaysinleague', 'mlb'],
#  ['vanderbilt_university', 'teamplaysinleague', 'international'],
#  ['trent_university', 'teamplaysinleague', 'international'],
#  ['illinois_state_university', 'teamplaysinleague', 'international'],
#  ['dixie_state_rebels', 'teamplaysinleague', 'ncaa'],
#  ['nanjing_university', 'teamplaysinleague', 'international'],
#  ['carolina_panthers', 'teamplaysinleague', 'nfl'],
#  ['oklahoma_state_cowboys', 'teamplaysinleague', 'ncaa'],
#  ['cleveland_indians_organization', 'teamplaysinleague', 'mlb'],
#  ['sacramento_monarchs', 'teamplaysinleague', 'wnba'],
#  ['boston_celtics', 'teamplaysinleague', 'nba'],
#  ['packers', 'teamplaysinleague', 'nfl'],
#  ['st__louis_billikens', 'teamplaysinleague', 'ncaa'],
#  ['susquehanna_crusaders', 'teamplaysinleague', 'ncaa'],
#  ['dickinson_college', 'teamplaysinleague', 'international'],
#  ['lincoln_lions', 'teamplaysinleague', 'ncaa'],
#  ['colorado_state', 'teamplaysinleague', 'ncaa'],
#  ['monterey_institute_of_international_studies',
#   'teamplaysinleague',
#   'international'],
#  ['northern_michigan_wildcats', 'teamplaysinleague', 'ncaa'],
#  ['governors_state_university', 'teamplaysinleague', 'ncaa'],
#  ['le_moyne_college_dolphins', 'teamplaysinleague', 'ncaa'],
#  ['weber_state_wildcats', 'teamplaysinleague', 'ncaa'],
#  ['st_peters_peacocks', 'teamplaysinleague', 'ncaa'],
#  ['san_jose_st__spartans', 'teamplaysinleague', 'ncaa'],
#  ['air_force_academy_falcons', 'teamplaysinleague', 'ncaa'],
#  ['washburn_ichabods', 'teamplaysinleague', 'ncaa'],
#  ['clarion_golden_eagles', 'teamplaysinleague', 'ncaa'],
#  ['new_york_titans', 'teamplaysinleague', 'nfl'],
#  ['san_diego_st__aztecs', 'teamplaysinleague', 'ncaa'],
#  ['seattle_storm', 'teamplaysinleague', 'wnba'],
#  ['adelphi_university_panthers', 'teamplaysinleague', 'ncaa'],
#  ['bemidji_state_beavers', 'teamplaysinleague', 'ncaa'],
#  ['red_sox', 'teamplaysinleague', 'mlb'],
#  ['savannah_st__tigers', 'teamplaysinleague', 'ncaa'],
#  ['steelers', 'teamplaysinleague', 'nfl'],
#  ['michigan_tech_huskies', 'teamplaysinleague', 'ncaa'],
#  ['rochester_college', 'teamplaysinleague', 'ncaa'],
#  ['olson', 'teamplaysinleague', 'mlb']]

# %%
test_lst = [['matt_morri','athleteplaysinleague','mlb'],['brewers','athleteplaysinleague','mlb'],['tommie_agee','athleteplaysinleague','mlb'],['mariners', 'athleteplaysinleague', 'mlb']]

depth = 2
if depth > 0:
    
    tmp = []
    def x(xx):
        print(xx)
        for i in range(len(lst_data)):
            for j in range(len(xx)):
                if xx[j] == lst_data[i][0] or xx[j] == lst_data[i][2]:
                    if lst_data[i] not in test_lst:
                        test_lst.append(lst_data[i])
                        
    for i in range(len(test_lst)):
        tmp.append(test_lst[i][0])
    x(tmp)
                    
    if depth > 1:
        tt = []
        for i in range(len(test_lst)):
            if test_lst[i][0] not in tt:
                tt.append(test_lst[i][0])
        x(tt)
# Out:
# ['matt_morri', 'brewers', 'tommie_agee', 'mariners']
# ['matt_morri', 'brewers', 'tommie_agee', 'mariners', 'kenji_johjima']

# %%
test_lst
# Out:
# [['matt_morri', 'athleteplaysinleague', 'mlb'],
#  ['brewers', 'athleteplaysinleague', 'mlb'],
#  ['tommie_agee', 'athleteplaysinleague', 'mlb'],
#  ['mariners', 'athleteplaysinleague', 'mlb'],
#  ['brewers', 'teamplayssport', 'baseball'],
#  ['mariners', 'teamplayssport', 'baseball'],
#  ['kenji_johjima', 'athleteplaysforteam', 'mariners'],
#  ['mariners', 'teamplaysinleague', 'mlb']]

# %%
test_lst
# Out:
# [['matt_morri', 'athleteplaysinleague', 'mlb'],
#  ['brewers', 'athleteplaysinleague', 'mlb'],
#  ['tommie_agee', 'athleteplaysinleague', 'mlb'],
#  ['mariners', 'athleteplaysinleague', 'mlb'],
#  ['brewers', 'teamplayssport', 'baseball'],
#  ['mariners', 'teamplayssport', 'baseball'],
#  ['kenji_johjima', 'athleteplaysforteam', 'mariners'],
#  ['mariners', 'teamplaysinleague', 'mlb']]

# %%
depth = 1
if depth > 0:
    tmp = []
    def x():
        for i in range(len(lst_data)):
                for j in range(len(tmp)):
                    if tmp[j] in lst_data[i]:
                        if lst_data[i] not in test_lst:
                        test_lst.append(lst_data[i])
                        
    for i in range(len(test_lst)):
        tmp.append(test_lst[i][0])
    for i in range(len(lst_data)):
        for j in range(len(tmp)):
            if tmp[j] in lst_data[i]:
                if lst_data[i] not in test_lst:
                    test_lst.append(lst_data[i])
                    
    if depth > 1:
        tmp = []
        for i in range(len(lst_data)):
            tmp.append(lst_data[i][0])
        for i in range(len(lst_data)):
            for j in range(len(tmp)):
                if tmp[j] in lst_data[i]:
                    if lst_data[i] not in test_lst:
                    test_lst.append(lst_data[i])

# %%
test_lst
# Out:
# [['a', 'b', 'sport_baseball'],
#  ['coach_justin_miller', 'e', 'sport_baseball'],
#  ['g', 'h', 'sport_baseball'],
#  ['sportsteam_mariners', 'teamplayssport', 'sport_baseball'],
#  ['coach_justin_miller', 'athleteplaysinleague', 'sportsleague_nfl'],
#  ['athlete_kenji_johjima', 'athleteplaysforteam', 'sportsteam_mariners'],
#  ['sportsteam_mariners', 'teamplaysinleague', 'sportsleague_mlb']]

# %%
ls
# Out:
# displayData.json* pyTest.ipynb      test_data.nt*
# draw.json*        testKobe.nt

# %% [markdown]
# # test

# %%
dataPath = 'test.nt'

# %%
l = []
l_org = []

# %%
input_file = open(dataPath, 'r')

# %%
for line in input_file:
    s, p, o = line.replace('\n', '').replace("concept:", '').replace("concept_", '').split('\t')
    s = s.replace(s.split('_')[0] + '_', '')
    o = o.replace(o.split('_')[0] + '_', '')
    if "latitudelongitude" not in p:
        l_org.append([s, p, o])
        l.append([s, p, o])

# %%
l_org
# Out:
# [['christopher_nolan', 'coworker', 'david_s._goyer'],
#  ['christopher_nolan', 'coworker', 'bob_kane'],
#  ['christopher_nolan', 'coworker', 'christian_bale'],
#  ['christopher_nolan', 'coworker', 'liam_neeson'],
#  ['christopher_nolan', 'coworker', 'michael_caine'],
#  ['christopher_nolan', 'coworker', 'katie_holmes'],
#  ['david_s._goyer', 'coworker', 'bob_kane'],
#  ['david_s._goyer', 'coworker', 'christian_bale'],
#  ['david_s._goyer', 'coworker', 'liam_neeson'],
#  ['david_s._goyer', 'coworker', 'michael_caine'],
#  ['david_s._goyer', 'coworker', 'katie_holmes'],
#  ['bob_kane', 'coworker', 'christian_bale'],
#  ['bob_kane', 'coworker', 'liam_neeson'],
#  ['bob_kane', 'coworker', 'michael_caine'],
#  ['bob_kane', 'coworker', 'katie_holmes'],
#  ['christian_bale', 'coworker', 'liam_neeson'],
#  ['christian_bale', 'coworker', 'michael_caine'],
#  ['christian_bale', 'coworker', 'katie_holmes'],
#  ['liam_neeson', 'coworker', 'michael_caine'],
#  ['liam_neeson', 'coworker', 'katie_holmes'],
#  ['michael_caine', 'coworker', 'katie_holmes'],
#  ['batman_begins', 'directed_by', 'christopher_nolan'],
#  ['batman_begins', 'written_by', 'christopher_nolan'],
#  ['batman_begins', 'written_by', 'david_s._goyer'],
#  ['batman_begins', 'written_by', 'bob_kane'],
#  ['batman_begins', 'starred_actors', 'christian_bale'],
#  ['batman_begins', 'starred_actors', 'liam_neeson'],
#  ['batman_begins', 'starred_actors', 'michael_caine'],
#  ['batman_begins', 'starred_actors', 'katie_holmes'],
#  ['batman_begins', 'release_year', '2005'],
#  ['batman_begins', 'in_language', 'english'],
#  ['batman_begins', 'in_language', 'mandarin'],
#  ['batman_begins', 'in_language', 'urdu'],
#  ['batman_begins', 'has_genre', 'action'],
#  ['batman_begins', 'has_genre', 'adventure'],
#  ['batman_begins', 'has_imdb_rating', 'fantastic'],
#  ['batman_begins', 'has_imdb_votes', 'famous'],
#  ['batman_begins', 'has_tags', 'atmospheric'],
#  ['batman_begins', 'has_tags', 'action'],
#  ['batman_begins', 'has_tags', 'stylized'],
#  ['batman_begins', 'has_tags', 'thought-provoking'],
#  ['batman_begins', 'has_tags', 'dark'],
#  ['batman_begins', 'has_tags', 'imdb_top_250'],
#  ['batman_begins', 'has_tags', 'superhero'],
#  ['batman_begins', 'has_tags', 'crime'],
#  ['batman_begins', 'has_tags', 'comic_book'],
#  ['batman_begins', 'has_tags', 'dvd-video'],
#  ['batman_begins', 'has_tags', 'franchise'],
#  ['batman_begins', 'has_tags', "erlend's_dvds"],
#  ['batman_begins', 'has_tags', 'stupid'],
#  ['batman_begins', 'has_tags', 'police'],
#  ['batman_begins', 'has_tags', 'slow'],
#  ['batman_begins', 'has_tags', 'morgan_freeman'],
#  ['batman_begins', 'has_tags', 'soundtrack'],
#  ['batman_begins', 'has_tags', 'dvd'],
#  ['batman_begins', 'has_tags', 'christian_bale'],
#  ['batman_begins', 'has_tags', 'philosophical'],
#  ['batman_begins', 'has_tags', 'gritty'],
#  ['batman_begins', 'has_tags', 'melancholy'],
#  ['batman_begins', 'has_tags', 'michael_caine'],
#  ['batman_begins', 'has_tags', 'batman'],
#  ['batman_begins', 'has_tags', 'gary_oldman'],
#  ['batman_begins', 'has_tags', 'seen_at_the_cinema'],
#  ['batman_begins', 'has_tags', 'adapted_from:comic'],
#  ['batman_begins', 'has_tags', 'based_on_a_comic'],
#  ['batman_begins', 'has_tags', 'divx'],
#  ['batman_begins', 'has_tags', 'anti-hero'],
#  ['batman_begins', 'has_tags', 'liam_neeson'],
#  ['batman_begins', 'has_tags', 'owned'],
#  ['batman_begins', 'has_tags', 'super-hero'],
#  ['batman_begins', 'has_tags', 'dark_hero'],
#  ['batman_begins', 'has_tags', 'big_budget'],
#  ['batman_begins', 'has_tags', 'vigilante'],
#  ['batman_begins', 'has_tags', 'christopher_nolan'],
#  ['batman_begins', 'has_tags', "eric's_dvds"],
#  ['batman_begins', 'has_tags', 'pg-13'],
#  ['batman_begins', 'has_tags', 'baseball'],
#  ['batman_begins', 'has_tags', 'want_to_see_again'],
#  ['batman_begins', 'has_tags', 'scifi'],
#  ['batman_begins', 'has_tags', 'good_acting'],
#  ['batman_begins', 'has_tags', 'alter_ego'],
#  ['batman_begins', 'has_tags', 'amazing_cinematography'],
#  ['batman_begins', 'has_tags', 'moody'],
#  ['batman_begins', 'has_tags', 'gfei_own_it'],
#  ['batman_begins', 'has_tags', 'imax_dmr'],
#  ['batman_begins', 'has_tags', 'super_hero'],
#  ['batman_begins', 'has_tags', 'cillian_murphy'],
#  ['batman_begins', 'has_tags', 'double_life'],
#  ['batman_begins', 'has_tags', 'scope'],
#  ['batman_begins', 'has_tags', 'ninja'],
#  ['batman_begins', 'has_tags', 'want'],
#  ['batman_begins', 'has_tags', 'dc_comics'],
#  ['batman_begins', 'has_tags', 'vigilantism'],
#  ['batman_begins', 'has_tags', 'great_cast'],
#  ['batman_begins', 'has_tags', 'nocturnal'],
#  ['batman_begins', 'has_tags', 'based_on_comic'],
#  ['batman_begins', 'has_tags', 'prequel'],
#  ['batman_begins', 'has_tags', 'iceland'],
#  ['batman_begins', 'has_tags', 'favorites'],
#  ['batman_begins', 'has_tags', 'comics'],
#  ['batman_begins', 'has_tags', 'hans_zimmer'],
#  ['batman_begins', 'has_tags', 'great_story'],
#  ['batman_begins', 'has_tags', 'dc'],
#  ['batman_begins', 'has_tags', 'best_of_2005'],
#  ['batman_begins', 'has_tags', 'ken_watanabe'],
#  ['batman_begins', 'has_tags', 'katie_holmes'],
#  ['batman_begins', 'has_tags', 'saturn_award_(best_writing)'],
#  ['batman_begins', 'has_tags', 'comic'],
#  ['batman_begins', 'has_tags', 'watched_2005'],
#  ['batman_begins', 'has_tags', 'fear'],
#  ['batman_begins', 'has_tags', 'energy'],
#  ['batman_begins', 'has_tags', 'superheros'],
#  ['batman_begins', 'has_tags', 'batman_(series)'],
#  ['batman_begins', 'has_tags', 'gadget_car'],
#  ['batman_begins', 'has_tags', 'homelist1'],
#  ['batman_begins', 'has_tags', 'costumed_vigilante'],
#  ['batman_begins', 'has_tags', 'kinda_boring'],
#  ['batman_begins', 'has_tags', 'david_s._goyer'],
#  ['batman_begins', 'has_tags', 'batman_kills'],
#  ['batman_begins', 'has_tags', 'jump_cuts']]

# %%
data = pd.read_csv('../engineData/reasoning_output.csv', names=['e1','r','e2','score'])

# %%
data
# Out:
#                                       e1          r  \
# 0                 person_a.i._bezzerides  coworker
# 1                    person_a.p._younger  coworker
# 2            person_abderrahmane_sissako  coworker
# 3                    person_adam_kennedy  coworker
# 4                      person_adam_shirk  coworker
# 5                  person_adel_bencherif  coworker
# 6                 person_adriano_rimoldi  coworker
# 7       person_afshin_khorshid_bakhtiari  coworker
# 8                 person_agatha_christie  coworker
# 9                person_agenore_incrocci  coworker
# 10                    person_aidan_quinn  coworker
# 11            person_aimee-lynn_chadwick  coworker
# 12                   person_alain_chabat  coworker
# 13                   person_alan_caillou  coworker
# 14                       person_alan_cox  coworker
# 15                    person_alan_davies  coworker
# 16                    person_alan_parker  coworker
# 17                   person_alan_rickman  coworker
# 18                  person_albert_dekker  coworker
# 19                       person_aldo_ray  coworker
# 20                  person_alex_jennings  coworker
# 21               person_alexander_jacobs  coworker
# 22                  person_alexandre_aja  coworker
# 23                person_alexis_arquette  coworker
# 24                    person_alice_braga  coworker
# 25                    person_alice_david  coworker
# 26                    person_alida_valli  coworker
# 27                    person_amanda_lear  coworker
# 28                    person_amanda_noar  coworker
# 29                 person_amedeo_mellone  coworker
# ...                                  ...        ...
# 155344        person_vladimir_jabotinsky  coworker
# 155345              person_w.s._van_dyke  coworker
# 155346               person_wai-man_chan  coworker
# 155347             person_walter_brennan  coworker
# 155348              person_walter_farley  coworker
# 155349              person_walter_ferris  coworker
# 155350             person_walter_matthau  coworker
# 155351             person_walter_matthau  coworker
# 155352          person_wayne_bartholomew  coworker
# 155353              person_wendy_gazelle  coworker
# 155354              person_wesley_snipes  coworker
# 155355               person_willem_dafoe  coworker
# 155356        person_william_collier_jr.  coworker
# 155357             person_william_holden  coworker
# 155358               person_william_hurt  coworker
# 155359             person_william_ludwig  coworker
# 155360          person_william_r._lipman  coworker
# 155361             person_william_sadler  coworker
# 155362        person_william_shakespeare  coworker
# 155363        person_william_shakespeare  coworker
# 155364              person_william_smith  coworker
# 155365          person_winifred_kingston  coworker
# 155366        person_wolfgang_reitherman  coworker
# 155367           person_wolfgang_schenck  coworker
# 155368               person_wolfram_witt  coworker
# 155369                person_woody_allen  coworker
# 155370            person_woody_harrelson  coworker
# 155371                  person_zhang_fan  coworker
# 155372                person_zita_johann  coworker
# 155373                person_zulay_henao  coworker
#
#                                    e2     score
# 0              person_j._carrol_naish  1.000000
# 1                   person_mary_brian  1.000000
# 2              person_tiécoura_traoré  1.000000
# 3                  person_john_mcliam  1.000000
# 4                 person_maris_wrixon  1.000000
# 5              person_thomas_bidegain  1.000000
# 6            person_gherardo_gherardi  1.000000
# 7             person_safar_ali_moradi  1.000000
# 8                person_robert_morley  1.000000
# 9                person_tonino_guerra  1.000000
# 10               person_claudia_ferri  1.000000
# 11              person_jordan_kessler  1.000000
# 12           person_jean-pierre_bacri  1.000000
# 13               person_colin_mothupi  1.000000
# 14                 person_sophie_ward  1.000000
# 15             person_louise_rennison  1.000000
# 16                  person_lisa_bonet  1.000000
# 17              person_sidney_carroll  1.000000
# 18               person_helen_parrish  1.000000
# 19                   person_tom_conti  0.000001
# 20              person_james_cromwell  1.000000
# 21              person_toshirô_mifune  1.000000
# 22                     person_maïwenn  1.000000
# 23                person_hilary_swank  1.000000
# 24                person_nimród_antal  1.000000
# 25             person_nicolas_benamou  1.000000
# 26               person_graham_greene  1.000000
# 27              person_philippe_nahon  1.000000
# 28               person_dirk_campbell  1.000000
# 29             person_fernando_sancho  1.000000
# ...                               ...       ...
# 155344         person_jesse_lasky_jr.  1.000000
# 155345           person_mauri_grashin  1.000000
# 155346            person_raymond_fung  1.000000
# 155347          person_charles_schnee  1.000000
# 155348         person_richard_romanus  1.000000
# 155349           person_vera_reynolds  0.000001
# 155350             person_bernard_lee  0.000001
# 155351           person_dan_o'herlihy  1.000000
# 155352           person_edward_norton  1.000000
# 155353          person_laurence_heath  1.000000
# 155354             person_walon_green  0.000001
# 155355       person_annabella_sciorra  1.000000
# 155356           person_james_gleason  1.000000
# 155357           person_athene_seyler  1.000000
# 155358          person_romy_schneider  0.000001
# 155359           person_andy_griffith  0.000001
# 155360             person_tay_garnett  1.000000
# 155361         person_robert_zemeckis  1.000000
# 155362       person_natascha_mcelhone  1.000000
# 155363           person_ralph_fiennes  1.000000
# 155364           person_robert_clouse  1.000000
# 155365      person_edwin_milton_royle  1.000000
# 155366               person_joe_flynn  1.000000
# 155367         person_theodor_fontane  1.000000
# 155368            person_heiner_carow  1.000000
# 155369              person_ed_herlihy  1.000000
# 155370                 person_50_cent  1.000000
# 155371                 person_xin_huo  1.000000
# 155372           person_boris_karloff  1.000000
# 155373  person_daniel_stewart_sherman  1.000000
#
# [155374 rows x 4 columns]

# %%
relation = 'coworker'

# %%
runData = data[data['r'].str.contains(relation)].sort_values('score', ascending=False)

# %%
runData
# Out:
#                                  e1          r                          e2  \
# 0            person_a.i._bezzerides  coworker       person_j._carrol_naish
# 99602    person_alessandro_preziosi  coworker       person_nicole_grimaudo
# 99596              person_alan_alda  coworker           person_diane_drake
# 99597              person_alan_hale  coworker            person_ellen_drew
# 99598          person_albert_finney  coworker         person_neville_smith
# 99599         person_albert_hackett  coworker           person_van_johnson
# 99600          person_alec_guinness  coworker         person_robert_morley
# 99601      person_aleksandr_sokurov  coworker        person_elena_rufanova
# 99603          person_alfre_woodard  coworker            person_loren_dean
# 99593         person_aisling_loftus  coworker    person_margaret_humphreys
# 99604         person_alice_taglioni  coworker         person_francis_veber
# 99605         person_allison_anders  coworker      person_robert_rodriguez
# 99606              person_amy_adams  coworker       person_scott_alexander
# 99608        person_andrew_bujalski  coworker            person_todd_rohal
# 99609    person_andrew_kevin_walker  coworker       person_christine_lahti
# 99610     person_andrew_v._mclaglen  coworker     person_robert_h._adleman
# 99594            person_akira_emoto  coworker       person_akira_yoshimura
# 99592            person_aidan_quinn  coworker              person_tim_daly
# 99820     person_francesco_golisano  coworker      person_cesare_zavattini
# 99583          person_yôjirô_takita  coworker          person_kundô_koyama
# 99577          person_william_wyler  coworker           person_bette_davis
# 99578         person_xan_cassavetes  coworker         person_shekhar_kapur
# 99579               person_yao_meng  coworker           person_shunji_iwai
# 99580            person_yash_chopra  coworker          person_rani_mukerji
# 99581          person_yoko_sakamoto  coworker      person_tomomi_mochizuki
# 99582         person_yvette_mimieux  coworker             person_jim_brown
# 99584           person_yûsuke_iseya  coworker     person_kazunari_ninomiya
# 99591           person_adrien_brody  coworker        person_ralph_greenson
# 99585            person_zoe_saldana  coworker   person_jeffrey_dean_morgan
# 99586          person_aaron_woodley  coworker          person_david_weaver
# ...                             ...        ...                         ...
# 137830           person_julie_delpy  coworker         person_brian_goodman
# 17979          person_blake_edwards  coworker           person_ed_flanders
# 8734             person_daniel_mann  coworker           person_bette_davis
# 36774   person_h._bruce_humberstone  coworker       person_george_callahan
# 57397       person_shirley_maclaine  coworker            person_gene_kelly
# 16067           person_mike_nichols  coworker         person_kelly_preston
# 84213       person_alfred_hitchcock  coworker    person_corydon_m._wassell
# 88677      person_richard_fleischer  coworker         person_steve_mcqueen
# 17382         person_henry_hathaway  coworker       person_victor_mclaglen
# 18167             person_gene_kelly  coworker           person_tony_curtis
# 59929           person_allen_covert  coworker           person_kevin_james
# 103997    person_robert_n._bradbury  coworker         person_reginald_owen
# 78936     person_hamilton_macfadden  coworker         person_pauline_moore
# 94379             person_don_siegel  coworker           person_james_woods
# 67111         person_clarence_brown  coworker         person_warner_baxter
# 45676              person_sam_raimi  coworker       person_woody_harrelson
# 42475           person_nicholas_ray  coworker       person_joanne_woodward
# 57532       person_alfred_hitchcock  coworker            person_leo_rosten
# 49630       person_alfred_hitchcock  coworker        person_burt_lancaster
# 53801         person_ernst_lubitsch  coworker        person_ingrid_bergman
# 108806          person_anthony_mann  coworker          person_lamar_trotti
# 60646     person_william_a._wellman  coworker       person_benjamin_glazer
# 31407            person_karl_freund  coworker          person_garrett_fort
# 24296        person_edward_sedgwick  coworker            person_brown_eyes
# 130938             person_john_ford  coworker            person_dan_duryea
# 150817        person_clint_eastwood  coworker     person_samuel_l._jackson
# 73909      person_steven_soderbergh  coworker         person_paul_giamatti
# 50920              person_marc_caro  coworker        person_gaspard_ulliel
# 65383     person_andrew_v._mclaglen  coworker              person_aldo_ray
# 46102           person_ivan_reitman  coworker           person_john_cusack
#
#                score
# 0       1.000000e+00
# 99602   1.000000e+00
# 99596   1.000000e+00
# 99597   1.000000e+00
# 99598   1.000000e+00
# 99599   1.000000e+00
# 99600   1.000000e+00
# 99601   1.000000e+00
# 99603   1.000000e+00
# 99593   1.000000e+00
# 99604   1.000000e+00
# 99605   1.000000e+00
# 99606   1.000000e+00
# 99608   1.000000e+00
# 99609   1.000000e+00
# 99610   1.000000e+00
# 99594   1.000000e+00
# 99592   1.000000e+00
# 99820   1.000000e+00
# 99583   1.000000e+00
# 99577   1.000000e+00
# 99578   1.000000e+00
# 99579   1.000000e+00
# 99580   1.000000e+00
# 99581   1.000000e+00
# 99582   1.000000e+00
# 99584   1.000000e+00
# 99591   1.000000e+00
# 99585   1.000000e+00
# 99586   1.000000e+00
# ...              ...
# 137830  4.470348e-07
# 17979   4.470348e-07
# 8734    4.470348e-07
# 36774   4.470348e-07
# 57397   4.470348e-07
# 16067   4.470348e-07
# 84213   4.470348e-07
# 88677   4.470348e-07
# 17382   4.172325e-07
# 18167   4.172325e-07
# 59929   4.172325e-07
# 103997  4.172325e-07
# 78936   4.172325e-07
# 94379   3.874302e-07
# 67111   3.874302e-07
# 45676   3.874302e-07
# 42475   3.576279e-07
# 57532   3.576279e-07
# 49630   3.576279e-07
# 53801   3.576279e-07
# 108806  3.576279e-07
# 60646   3.576279e-07
# 31407   3.278255e-07
# 24296   3.278255e-07
# 130938  2.682209e-07
# 150817  2.384186e-07
# 73909   2.086163e-07
# 50920   2.086163e-07
# 65383   1.788139e-07
# 46102   1.192093e-07
#
# [155374 rows x 4 columns]

# %%
lst = runData.values.tolist()

# %%
len(lst)
# Out:
# 155374

# %%
threshold=1

# %%
def processing(tmp):
    if len(tmp) == 3:
        return [tmp[0].replace(tmp[0].split('_')[0] + '_', ''), tmp[1], tmp[2].replace(tmp[2].split('_')[0] + '_', '')]
    else:
        return [tmp[0].replace(tmp[0].split('_')[0] + '_', ''), tmp[1], tmp[2].replace(tmp[2].split('_')[0] + '_', ''), tmp[3]]

# %%
withScore = []
for i in range(len(l_org)):
    for j in range(len(lst)):
        if l_org[i][1] in lst[j][1]:
            if l_org[i][0] in lst[j][0]:
                if processing([lst[j][0],lst[j][1],lst[j][2]]) not in l:
                    withScore.append(processing([lst[j][0], lst[j][1], lst[j][2], round(lst[j][3], 3)]))
                    if lst[j][-1] >= threshold:
                        l.append(processing([lst[j][0], lst[j][1], lst[j][2]]))
#             if l_org[i][2] in lst[j][0] or l_org[i][0] in lst[j][2]:
#                 if processing([lst[j][0],lst[j][1],lst[j][2]]) not in l:
#                     withScore.append(processing([lst[j][0], lst[j][1], lst[j][2], round(lst[j][3], 3)]))
#                     if lst[j][-1] >= threshold:
#                         l.append(processing([lst[j][0], lst[j][1], lst[j][2]]))

# %%
len(l)
# Out:
# 285

# %%
l
# Out:
# [['christopher_nolan', 'coworker', 'david_s._goyer'],
#  ['christopher_nolan', 'coworker', 'bob_kane'],
#  ['christopher_nolan', 'coworker', 'christian_bale'],
#  ['christopher_nolan', 'coworker', 'liam_neeson'],
#  ['christopher_nolan', 'coworker', 'michael_caine'],
#  ['christopher_nolan', 'coworker', 'katie_holmes'],
#  ['david_s._goyer', 'coworker', 'bob_kane'],
#  ['david_s._goyer', 'coworker', 'christian_bale'],
#  ['david_s._goyer', 'coworker', 'liam_neeson'],
#  ['david_s._goyer', 'coworker', 'michael_caine'],
#  ['david_s._goyer', 'coworker', 'katie_holmes'],
#  ['bob_kane', 'coworker', 'christian_bale'],
#  ['bob_kane', 'coworker', 'liam_neeson'],
#  ['bob_kane', 'coworker', 'michael_caine'],
#  ['bob_kane', 'coworker', 'katie_holmes'],
#  ['christian_bale', 'coworker', 'liam_neeson'],
#  ['christian_bale', 'coworker', 'michael_caine'],
#  ['christian_bale', 'coworker', 'katie_holmes'],
#  ['liam_neeson', 'coworker', 'michael_caine'],
#  ['liam_neeson', 'coworker', 'katie_holmes'],
#  ['michael_caine', 'coworker', 'katie_holmes'],
#  ['batman_begins', 'directed_by', 'christopher_nolan'],
#  ['batman_begins', 'written_by', 'christopher_nolan'],
#  ['batman_begins', 'written_by', 'david_s._goyer'],
#  ['batman_begins', 'written_by', 'bob_kane'],
#  ['batman_begins', 'starred_actors', 'christian_bale'],
#  ['batman_begins', 'starred_actors', 'liam_neeson'],
#  ['batman_begins', 'starred_actors', 'michael_caine'],
#  ['batman_begins', 'starred_actors', 'katie_holmes'],
#  ['batman_begins', 'release_year', '2005'],
#  ['batman_begins', 'in_language', 'english'],
#  ['batman_begins', 'in_language', 'mandarin'],
#  ['batman_begins', 'in_language', 'urdu'],
#  ['batman_begins', 'has_genre', 'action'],
#  ['batman_begins', 'has_genre', 'adventure'],
#  ['batman_begins', 'has_imdb_rating', 'fantastic'],
#  ['batman_begins', 'has_imdb_votes', 'famous'],
#  ['batman_begins', 'has_tags', 'atmospheric'],
#  ['batman_begins', 'has_tags', 'action'],
#  ['batman_begins', 'has_tags', 'stylized'],
#  ['batman_begins', 'has_tags', 'thought-provoking'],
#  ['batman_begins', 'has_tags', 'dark'],
#  ['batman_begins', 'has_tags', 'imdb_top_250'],
#  ['batman_begins', 'has_tags', 'superhero'],
#  ['batman_begins', 'has_tags', 'crime'],
#  ['batman_begins', 'has_tags', 'comic_book'],
#  ['batman_begins', 'has_tags', 'dvd-video'],
#  ['batman_begins', 'has_tags', 'franchise'],
#  ['batman_begins', 'has_tags', "erlend's_dvds"],
#  ['batman_begins', 'has_tags', 'stupid'],
#  ['batman_begins', 'has_tags', 'police'],
#  ['batman_begins', 'has_tags', 'slow'],
#  ['batman_begins', 'has_tags', 'morgan_freeman'],
#  ['batman_begins', 'has_tags', 'soundtrack'],
#  ['batman_begins', 'has_tags', 'dvd'],
#  ['batman_begins', 'has_tags', 'christian_bale'],
#  ['batman_begins', 'has_tags', 'philosophical'],
#  ['batman_begins', 'has_tags', 'gritty'],
#  ['batman_begins', 'has_tags', 'melancholy'],
#  ['batman_begins', 'has_tags', 'michael_caine'],
#  ['batman_begins', 'has_tags', 'batman'],
#  ['batman_begins', 'has_tags', 'gary_oldman'],
#  ['batman_begins', 'has_tags', 'seen_at_the_cinema'],
#  ['batman_begins', 'has_tags', 'adapted_from:comic'],
#  ['batman_begins', 'has_tags', 'based_on_a_comic'],
#  ['batman_begins', 'has_tags', 'divx'],
#  ['batman_begins', 'has_tags', 'anti-hero'],
#  ['batman_begins', 'has_tags', 'liam_neeson'],
#  ['batman_begins', 'has_tags', 'owned'],
#  ['batman_begins', 'has_tags', 'super-hero'],
#  ['batman_begins', 'has_tags', 'dark_hero'],
#  ['batman_begins', 'has_tags', 'big_budget'],
#  ['batman_begins', 'has_tags', 'vigilante'],
#  ['batman_begins', 'has_tags', 'christopher_nolan'],
#  ['batman_begins', 'has_tags', "eric's_dvds"],
#  ['batman_begins', 'has_tags', 'pg-13'],
#  ['batman_begins', 'has_tags', 'baseball'],
#  ['batman_begins', 'has_tags', 'want_to_see_again'],
#  ['batman_begins', 'has_tags', 'scifi'],
#  ['batman_begins', 'has_tags', 'good_acting'],
#  ['batman_begins', 'has_tags', 'alter_ego'],
#  ['batman_begins', 'has_tags', 'amazing_cinematography'],
#  ['batman_begins', 'has_tags', 'moody'],
#  ['batman_begins', 'has_tags', 'gfei_own_it'],
#  ['batman_begins', 'has_tags', 'imax_dmr'],
#  ['batman_begins', 'has_tags', 'super_hero'],
#  ['batman_begins', 'has_tags', 'cillian_murphy'],
#  ['batman_begins', 'has_tags', 'double_life'],
#  ['batman_begins', 'has_tags', 'scope'],
#  ['batman_begins', 'has_tags', 'ninja'],
#  ['batman_begins', 'has_tags', 'want'],
#  ['batman_begins', 'has_tags', 'dc_comics'],
#  ['batman_begins', 'has_tags', 'vigilantism'],
#  ['batman_begins', 'has_tags', 'great_cast'],
#  ['batman_begins', 'has_tags', 'nocturnal'],
#  ['batman_begins', 'has_tags', 'based_on_comic'],
#  ['batman_begins', 'has_tags', 'prequel'],
#  ['batman_begins', 'has_tags', 'iceland'],
#  ['batman_begins', 'has_tags', 'favorites'],
#  ['batman_begins', 'has_tags', 'comics'],
#  ['batman_begins', 'has_tags', 'hans_zimmer'],
#  ['batman_begins', 'has_tags', 'great_story'],
#  ['batman_begins', 'has_tags', 'dc'],
#  ['batman_begins', 'has_tags', 'best_of_2005'],
#  ['batman_begins', 'has_tags', 'ken_watanabe'],
#  ['batman_begins', 'has_tags', 'katie_holmes'],
#  ['batman_begins', 'has_tags', 'saturn_award_(best_writing)'],
#  ['batman_begins', 'has_tags', 'comic'],
#  ['batman_begins', 'has_tags', 'watched_2005'],
#  ['batman_begins', 'has_tags', 'fear'],
#  ['batman_begins', 'has_tags', 'energy'],
#  ['batman_begins', 'has_tags', 'superheros'],
#  ['batman_begins', 'has_tags', 'batman_(series)'],
#  ['batman_begins', 'has_tags', 'gadget_car'],
#  ['batman_begins', 'has_tags', 'homelist1'],
#  ['batman_begins', 'has_tags', 'costumed_vigilante'],
#  ['batman_begins', 'has_tags', 'kinda_boring'],
#  ['batman_begins', 'has_tags', 'david_s._goyer'],
#  ['batman_begins', 'has_tags', 'batman_kills'],
#  ['batman_begins', 'has_tags', 'jump_cuts'],
#  ['christopher_nolan', 'coworker ', "oliver_'ole'_zemen"],
#  ['christopher_nolan', 'coworker ', 'bob_kane'],
#  ['christopher_nolan', 'coworker ', 'mark_boone_junior'],
#  ['christopher_nolan', 'coworker ', 'katie_holmes'],
#  ['christopher_nolan', 'coworker ', 'hilary_swank'],
#  ['christopher_nolan', 'coworker ', 'hillary_seitz'],
#  ['christopher_nolan', 'coworker ', 'jerry_siegel'],
#  ['christopher_nolan', 'coworker ', 'christopher_priest'],
#  ['christopher_nolan', 'coworker ', 'ellen_burstyn'],
#  ['christopher_nolan', 'coworker ', 'mackenzie_foy'],
#  ['david_s._goyer', 'coworker ', 'jean-claude_van_damme'],
#  ['david_s._goyer', 'coworker ', 'deran_sarafian'],
#  ['david_s._goyer', 'coworker ', 'stephen_norrington'],
#  ['david_s._goyer', 'coworker ', 'william_hurt'],
#  ['david_s._goyer', 'coworker ', 'jonathan_nolan'],
#  ['david_s._goyer', 'coworker ', 'jim_uhls'],
#  ['david_s._goyer', 'coworker ', 'natasha_gregson_wagner'],
#  ['david_s._goyer', 'coworker ', 'lem_dobbs'],
#  ['david_s._goyer', 'coworker ', 'stephen_dorff'],
#  ['david_s._goyer', 'coworker ', 'robert_a._heinlein'],
#  ['david_s._goyer', 'coworker ', 'justin_chatwin'],
#  ['david_s._goyer', 'coworker ', 'ron_perlman'],
#  ['david_s._goyer', 'coworker ', 'michael_shannon'],
#  ['bob_kane', 'coworker ', 'thomas_gibson'],
#  ['bob_kane', 'coworker ', 'michael_goguen'],
#  ['bob_kane', 'coworker ', 'val_kilmer'],
#  ['bob_kane', 'coworker ', 'tom_kenny'],
#  ['bob_kane', 'coworker ', 'victor_mcleod'],
#  ['bob_kane', 'coworker ', 'christopher_walken'],
#  ['bob_kane', 'coworker ', 'joel_schumacher'],
#  ['bob_kane', 'coworker ', 'jim_carrey'],
#  ['bob_kane', 'coworker ', 'ray_walston'],
#  ['bob_kane', 'coworker ', 'doris_day'],
#  ['bob_kane', 'coworker ', 'john_d._brancato'],
#  ['bob_kane', 'coworker ', 'christopher_nolan'],
#  ['christian_bale', 'coworker ', 'eric_warren_singer'],
#  ['christian_bale', 'coworker ', 'samuel_l._jackson'],
#  ['christian_bale', 'coworker ', 'justin_theroux'],
#  ['christian_bale', 'coworker ', 'guinevere_turner'],
#  ['christian_bale', 'coworker ', 'david_ayer'],
#  ['christian_bale', 'coworker ', 'michael_ferris'],
#  ['christian_bale', 'coworker ', 'julian_barnes'],
#  ['christian_bale', 'coworker ', 'daniel_benzali'],
#  ['christian_bale', 'coworker ', 'keith_dorrington'],
#  ['christian_bale', 'coworker ', 'astrid_lindgren'],
#  ['christian_bale', 'coworker ', 'john_sharian'],
#  ['christian_bale', 'coworker ', 'jonathan_marc_feldman'],
#  ['christian_bale', 'coworker ', 'frank_whaley'],
#  ['christian_bale', 'coworker ', 'melissa_leo'],
#  ['christian_bale', 'coworker ', 'tom_stoppard'],
#  ['christian_bale', 'coworker ', 'david_o._russell'],
#  ['christian_bale', 'coworker ', 'shawn_slovo'],
#  ['christian_bale', 'coworker ', 'eva_longoria'],
#  ['christian_bale', 'coworker ', 'david_s._goyer'],
#  ['christian_bale', 'coworker ', 'katie_holmes'],
#  ['christian_bale', 'coworker ', 'paul_tamasy'],
#  ['christian_bale', 'coworker ', 'liam_neeson'],
#  ['christian_bale', 'coworker ', 'natascha_mcelhone'],
#  ['christian_bale', 'coworker ', 'sam_worthington'],
#  ['christian_bale', 'coworker ', 'zach_grenier'],
#  ['liam_neeson', 'coworker ', 'david_johnson'],
#  ['liam_neeson', 'coworker ', 'agnieszka_wojtowicz-vosloo'],
#  ['liam_neeson', 'coworker ', 'michael_wincott'],
#  ['liam_neeson', 'coworker ', "quinton_'rampage'_jackson"],
#  ['liam_neeson', 'coworker ', 'famke_janssen'],
#  ['liam_neeson', 'coworker ', 'diane_keaton'],
#  ['liam_neeson', 'coworker ', 'michael_delorenzo'],
#  ['liam_neeson', 'coworker ', 'shirley_jackson'],
#  ['liam_neeson', 'coworker ', 'michael_caton-jones'],
#  ['liam_neeson', 'coworker ', 'michael_bortman'],
#  ['liam_neeson', 'coworker ', 'richard_eyre'],
#  ['liam_neeson', 'coworker ', 'tate_donovan'],
#  ['liam_neeson', 'coworker ', 'clint_eastwood'],
#  ['liam_neeson', 'coworker ', 'xander_berkeley'],
#  ['liam_neeson', 'coworker ', 'jaume_collet-serra'],
#  ['liam_neeson', 'coworker ', 'katie_holmes'],
#  ['liam_neeson', 'coworker ', 'joan_freeman'],
#  ['liam_neeson', 'coworker ', 'robert_reece'],
#  ['liam_neeson', 'coworker ', 'frances_mcdormand'],
#  ['liam_neeson', 'coworker ', 'edward_furlong'],
#  ['liam_neeson', 'coworker ', 'maggie_grace'],
#  ['liam_neeson', 'coworker ', 'caroline_goodall'],
#  ['liam_neeson', 'coworker ', 'greg_macgillivray'],
#  ['liam_neeson', 'coworker ', 'maurice_compte'],
#  ['liam_neeson', 'coworker ', 'oliver_butcher'],
#  ['liam_neeson', 'coworker ', 'travis_beacham'],
#  ['liam_neeson', 'coworker ', 'paul_vosloo'],
#  ['liam_neeson', 'coworker ', 'julia_roberts'],
#  ['liam_neeson', 'coworker ', 'natasha_richardson'],
#  ['liam_neeson', 'coworker ', 'lawrence_block'],
#  ['liam_neeson', 'coworker ', 'catherine_zeta-jones'],
#  ['liam_neeson', 'coworker ', 'anne_fontaine'],
#  ['liam_neeson', 'coworker ', 'frank_grillo'],
#  ['liam_neeson', 'coworker ', 'ed_harris'],
#  ['liam_neeson', 'coworker ', 'peter_lepeniotis'],
#  ['liam_neeson', 'coworker ', 'susan_isaacs'],
#  ['liam_neeson', 'coworker ', 'david_von_ancken'],
#  ['liam_neeson', 'coworker ', 'bob_kane'],
#  ['liam_neeson', 'coworker ', 'robert_mark_kamen'],
#  ['liam_neeson', 'coworker ', 'pierre_morel'],
#  ['liam_neeson', 'coworker ', 'john_madden'],
#  ['liam_neeson', 'coworker ', 'justine_bateman'],
#  ['liam_neeson', 'coworker ', 'larry_drake'],
#  ['liam_neeson', 'coworker ', 'antonio_banderas'],
#  ['liam_neeson', 'coworker ', 'bradley_cooper'],
#  ['michael_caine', 'coworker ', 'jane_fonda'],
#  ['michael_caine', 'coworker ', 'guy_hamilton'],
#  ['michael_caine', 'coworker ', 'nelson_gidding'],
#  ['michael_caine', 'coworker ', 'britt_ekland'],
#  ['michael_caine', 'coworker ', 'john_sturges'],
#  ['michael_caine', 'coworker ', 'gladys_hill'],
#  ['michael_caine', 'coworker ', 'patrick_kavanagh'],
#  ['michael_caine', 'coworker ', 'ivan_passer'],
#  ['michael_caine', 'coworker ', 'evan_jones'],
#  ['michael_caine', 'coworker ', 'alvin_sargent'],
#  ['michael_caine', 'coworker ', 'mark_rydell'],
#  ['michael_caine', 'coworker ', 'curd_jürgens'],
#  ['michael_caine', 'coworker ', 'dan_fogelman'],
#  ['michael_caine', 'coworker ', 'michael_keaton'],
#  ['michael_caine', 'coworker ', 'christian_bale'],
#  ['michael_caine', 'coworker ', 'lewis_gilbert'],
#  ['michael_caine', 'coworker ', 'willy_russell'],
#  ['michael_caine', 'coworker ', 'kenneth_branagh'],
#  ['michael_caine', 'coworker ', 'michael_williams'],
#  ['michael_caine', 'coworker ', 'marc_brandel'],
#  ['michael_caine', 'coworker ', 'maggie_smith'],
#  ['michael_caine', 'coworker ', 'frances_barber'],
#  ['michael_caine', 'coworker ', 'robert_kaufman'],
#  ['michael_caine', 'coworker ', 'guy_green'],
#  ['michael_caine', 'coworker ', 'herbert_lom'],
#  ['michael_caine', 'coworker ', 'brendan_fraser'],
#  ['michael_caine', 'coworker ', 'phillip_noyce'],
#  ['michael_caine', 'coworker ', 'shirley_maclaine'],
#  ['michael_caine', 'coworker ', 'paul_hubschmid'],
#  ['michael_caine', 'coworker ', 'oskar_homolka'],
#  ['michael_caine', 'coworker ', 'diahann_carroll'],
#  ['michael_caine', 'coworker ', 'katya_gilden'],
#  ['michael_caine', 'coworker ', 'steve_conrad'],
#  ['michael_caine', 'coworker ', 'rod_hardy'],
#  ['michael_caine', 'coworker ', 'ben_kingsley'],
#  ['michael_caine', 'coworker ', 'juan_gabriel_yacuzzi'],
#  ['michael_caine', 'coworker ', 'ed_begley'],
#  ['michael_caine', 'coworker ', 'jeffrey_jones'],
#  ['michael_caine', 'coworker ', 'sol_saks'],
#  ['michael_caine', 'coworker ', 'ronald_harwood'],
#  ['michael_caine', 'coworker ', 'james_belushi'],
#  ['michael_caine', 'coworker ', 'ian_bannen'],
#  ['michael_caine', 'coworker ', 'dyan_cannon'],
#  ['michael_caine', 'coworker ', 'liam_neeson'],
#  ['michael_caine', 'coworker ', 'katie_holmes'],
#  ['michael_caine', 'coworker ', 'millicent_martin'],
#  ['michael_caine', 'coworker ', 'jonathan_nolan'],
#  ['michael_caine', 'coworker ', 'geoffrey_rush'],
#  ['michael_caine', 'coworker ', 'paul_gallico'],
#  ['michael_caine', 'coworker ', 'harold_nebenzal'],
#  ['michael_caine', 'coworker ', 'lionel_stander'],
#  ['michael_caine', 'coworker ', 'irwin_allen'],
#  ['michael_caine', 'coworker ', 'glenne_headly'],
#  ['michael_caine', 'coworker ', 'neil_simon'],
#  ['michael_caine', 'coworker ', 'nora_ephron'],
#  ['michael_caine', 'coworker ', 'peter_collinson'],
#  ['michael_caine', 'coworker ', 'sean_connery'],
#  ['michael_caine', 'coworker ', 'alfonso_cuarón'],
#  ['michael_caine', 'coworker ', 'neil_jordan'],
#  ['michael_caine', 'coworker ', 'john_phillip_law']]

# %%
len(withScore)
# Out:
# 351

# %%
withScore
# Out:
# [['christopher_nolan', 'coworker ', "oliver_'ole'_zemen", 1.0],
#  ['christopher_nolan', 'coworker ', 'bob_kane', 1.0],
#  ['christopher_nolan', 'coworker ', 'mark_boone_junior', 1.0],
#  ['christopher_nolan', 'coworker ', 'katie_holmes', 1.0],
#  ['christopher_nolan', 'coworker ', 'hilary_swank', 1.0],
#  ['christopher_nolan', 'coworker ', 'hillary_seitz', 1.0],
#  ['christopher_nolan', 'coworker ', 'jerry_siegel', 1.0],
#  ['christopher_nolan', 'coworker ', 'christopher_priest', 1.0],
#  ['christopher_nolan', 'coworker ', 'ellen_burstyn', 1.0],
#  ['christopher_nolan', 'coworker ', 'mackenzie_foy', 1.0],
#  ['david_s._goyer', 'coworker ', 'jean-claude_van_damme', 1.0],
#  ['david_s._goyer', 'coworker ', 'deran_sarafian', 1.0],
#  ['david_s._goyer', 'coworker ', 'stephen_norrington', 1.0],
#  ['david_s._goyer', 'coworker ', 'william_hurt', 1.0],
#  ['david_s._goyer', 'coworker ', 'jonathan_nolan', 1.0],
#  ['david_s._goyer', 'coworker ', 'jim_uhls', 1.0],
#  ['david_s._goyer', 'coworker ', 'natasha_gregson_wagner', 1.0],
#  ['david_s._goyer', 'coworker ', 'lem_dobbs', 1.0],
#  ['david_s._goyer', 'coworker ', 'stephen_dorff', 1.0],
#  ['david_s._goyer', 'coworker ', 'robert_a._heinlein', 1.0],
#  ['david_s._goyer', 'coworker ', 'justin_chatwin', 1.0],
#  ['david_s._goyer', 'coworker ', 'ron_perlman', 1.0],
#  ['david_s._goyer', 'coworker ', 'michael_shannon', 1.0],
#  ['david_s._goyer', 'coworker ', 'alan_north', 0.0],
#  ['david_s._goyer', 'coworker ', 'joseph_wilson', 0.0],
#  ['david_s._goyer', 'coworker ', 'rino_romano', 0.0],
#  ['david_s._goyer', 'coworker ', 'laura_fraser', 0.0],
#  ['david_s._goyer', 'coworker ', 'alan_north', 0.0],
#  ['david_s._goyer', 'coworker ', 'joseph_wilson', 0.0],
#  ['david_s._goyer', 'coworker ', 'rino_romano', 0.0],
#  ['david_s._goyer', 'coworker ', 'laura_fraser', 0.0],
#  ['david_s._goyer', 'coworker ', 'alan_north', 0.0],
#  ['david_s._goyer', 'coworker ', 'joseph_wilson', 0.0],
#  ['david_s._goyer', 'coworker ', 'rino_romano', 0.0],
#  ['david_s._goyer', 'coworker ', 'laura_fraser', 0.0],
#  ['david_s._goyer', 'coworker ', 'alan_north', 0.0],
#  ['david_s._goyer', 'coworker ', 'joseph_wilson', 0.0],
#  ['david_s._goyer', 'coworker ', 'rino_romano', 0.0],
#  ['david_s._goyer', 'coworker ', 'laura_fraser', 0.0],
#  ['david_s._goyer', 'coworker ', 'alan_north', 0.0],
#  ['david_s._goyer', 'coworker ', 'joseph_wilson', 0.0],
#  ['david_s._goyer', 'coworker ', 'rino_romano', 0.0],
#  ['david_s._goyer', 'coworker ', 'laura_fraser', 0.0],
#  ['bob_kane', 'coworker ', 'thomas_gibson', 1.0],
#  ['bob_kane', 'coworker ', 'michael_goguen', 1.0],
#  ['bob_kane', 'coworker ', 'val_kilmer', 1.0],
#  ['bob_kane', 'coworker ', 'tom_kenny', 1.0],
#  ['bob_kane', 'coworker ', 'victor_mcleod', 1.0],
#  ['bob_kane', 'coworker ', 'christopher_walken', 1.0],
#  ['bob_kane', 'coworker ', 'joel_schumacher', 1.0],
#  ['bob_kane', 'coworker ', 'jim_carrey', 1.0],
#  ['bob_kane', 'coworker ', 'ray_walston', 1.0],
#  ['bob_kane', 'coworker ', 'doris_day', 1.0],
#  ['bob_kane', 'coworker ', 'john_d._brancato', 1.0],
#  ['bob_kane', 'coworker ', 'christopher_nolan', 1.0],
#  ['bob_kane', 'coworker ', 'richard_burton', 0.0],
#  ['bob_kane', 'coworker ', 'patricia_clarkson', 0.0],
#  ['bob_kane', 'coworker ', 'stephen_gaghan', 0.0],
#  ['bob_kane', 'coworker ', 'richard_burton', 0.0],
#  ['bob_kane', 'coworker ', 'patricia_clarkson', 0.0],
#  ['bob_kane', 'coworker ', 'stephen_gaghan', 0.0],
#  ['bob_kane', 'coworker ', 'richard_burton', 0.0],
#  ['bob_kane', 'coworker ', 'patricia_clarkson', 0.0],
#  ['bob_kane', 'coworker ', 'stephen_gaghan', 0.0],
#  ['bob_kane', 'coworker ', 'richard_burton', 0.0],
#  ['bob_kane', 'coworker ', 'patricia_clarkson', 0.0],
#  ['bob_kane', 'coworker ', 'stephen_gaghan', 0.0],
#  ['christian_bale', 'coworker ', 'eric_warren_singer', 1.0],
#  ['christian_bale', 'coworker ', 'samuel_l._jackson', 1.0],
#  ['christian_bale', 'coworker ', 'justin_theroux', 1.0],
#  ['christian_bale', 'coworker ', 'guinevere_turner', 1.0],
#  ['christian_bale', 'coworker ', 'david_ayer', 1.0],
#  ['christian_bale', 'coworker ', 'michael_ferris', 1.0],
#  ['christian_bale', 'coworker ', 'julian_barnes', 1.0],
#  ['christian_bale', 'coworker ', 'daniel_benzali', 1.0],
#  ['christian_bale', 'coworker ', 'keith_dorrington', 1.0],
#  ['christian_bale', 'coworker ', 'astrid_lindgren', 1.0],
#  ['christian_bale', 'coworker ', 'john_sharian', 1.0],
#  ['christian_bale', 'coworker ', 'jonathan_marc_feldman', 1.0],
#  ['christian_bale', 'coworker ', 'frank_whaley', 1.0],
#  ['christian_bale', 'coworker ', 'melissa_leo', 1.0],
#  ['christian_bale', 'coworker ', 'tom_stoppard', 1.0],
#  ['christian_bale', 'coworker ', 'david_o._russell', 1.0],
#  ['christian_bale', 'coworker ', 'shawn_slovo', 1.0],
#  ['christian_bale', 'coworker ', 'eva_longoria', 1.0],
#  ['christian_bale', 'coworker ', 'david_s._goyer', 1.0],
#  ['christian_bale', 'coworker ', 'katie_holmes', 1.0],
#  ['christian_bale', 'coworker ', 'paul_tamasy', 1.0],
#  ['christian_bale', 'coworker ', 'liam_neeson', 1.0],
#  ['christian_bale', 'coworker ', 'natascha_mcelhone', 1.0],
#  ['christian_bale', 'coworker ', 'sam_worthington', 1.0],
#  ['christian_bale', 'coworker ', 'zach_grenier', 1.0],
#  ['christian_bale', 'coworker ', 'julie_delpy', 0.0],
#  ['christian_bale', 'coworker ', 'holmes_herbert', 0.0],
#  ['christian_bale', 'coworker ', 'john_fante', 0.0],
#  ['christian_bale', 'coworker ', 'don_houghton', 0.0],
#  ['christian_bale', 'coworker ', 'steve_conrad', 0.0],
#  ['christian_bale', 'coworker ', 'kelly_marcel', 0.0],
#  ['christian_bale', 'coworker ', 'pamela_reed', 0.0],
#  ['christian_bale', 'coworker ', 'hertel_minkner', 0.0],
#  ['christian_bale', 'coworker ', 'rex_burns', 0.0],
#  ['christian_bale', 'coworker ', 'adam_fields', 0.0],
#  ['christian_bale', 'coworker ', 'terence_fisher', 0.0],
#  ['christian_bale', 'coworker ', 'julie_delpy', 0.0],
#  ['christian_bale', 'coworker ', 'holmes_herbert', 0.0],
#  ['christian_bale', 'coworker ', 'john_fante', 0.0],
#  ['christian_bale', 'coworker ', 'don_houghton', 0.0],
#  ['christian_bale', 'coworker ', 'steve_conrad', 0.0],
#  ['christian_bale', 'coworker ', 'kelly_marcel', 0.0],
#  ['christian_bale', 'coworker ', 'pamela_reed', 0.0],
#  ['christian_bale', 'coworker ', 'hertel_minkner', 0.0],
#  ['christian_bale', 'coworker ', 'rex_burns', 0.0],
#  ['christian_bale', 'coworker ', 'adam_fields', 0.0],
#  ['christian_bale', 'coworker ', 'terence_fisher', 0.0],
#  ['christian_bale', 'coworker ', 'julie_delpy', 0.0],
#  ['christian_bale', 'coworker ', 'holmes_herbert', 0.0],
#  ['christian_bale', 'coworker ', 'john_fante', 0.0],
#  ['christian_bale', 'coworker ', 'don_houghton', 0.0],
#  ['christian_bale', 'coworker ', 'steve_conrad', 0.0],
#  ['christian_bale', 'coworker ', 'kelly_marcel', 0.0],
#  ['christian_bale', 'coworker ', 'pamela_reed', 0.0],
#  ['christian_bale', 'coworker ', 'hertel_minkner', 0.0],
#  ['christian_bale', 'coworker ', 'rex_burns', 0.0],
#  ['christian_bale', 'coworker ', 'adam_fields', 0.0],
#  ['christian_bale', 'coworker ', 'terence_fisher', 0.0],
#  ['liam_neeson', 'coworker ', 'david_johnson', 1.0],
#  ['liam_neeson', 'coworker ', 'agnieszka_wojtowicz-vosloo', 1.0],
#  ['liam_neeson', 'coworker ', 'michael_wincott', 1.0],
#  ['liam_neeson', 'coworker ', "quinton_'rampage'_jackson", 1.0],
#  ['liam_neeson', 'coworker ', 'famke_janssen', 1.0],
#  ['liam_neeson', 'coworker ', 'diane_keaton', 1.0],
#  ['liam_neeson', 'coworker ', 'michael_delorenzo', 1.0],
#  ['liam_neeson', 'coworker ', 'shirley_jackson', 1.0],
#  ['liam_neeson', 'coworker ', 'michael_caton-jones', 1.0],
#  ['liam_neeson', 'coworker ', 'michael_bortman', 1.0],
#  ['liam_neeson', 'coworker ', 'richard_eyre', 1.0],
#  ['liam_neeson', 'coworker ', 'tate_donovan', 1.0],
#  ['liam_neeson', 'coworker ', 'clint_eastwood', 1.0],
#  ['liam_neeson', 'coworker ', 'xander_berkeley', 1.0],
#  ['liam_neeson', 'coworker ', 'jaume_collet-serra', 1.0],
#  ['liam_neeson', 'coworker ', 'katie_holmes', 1.0],
#  ['liam_neeson', 'coworker ', 'joan_freeman', 1.0],
#  ['liam_neeson', 'coworker ', 'robert_reece', 1.0],
#  ['liam_neeson', 'coworker ', 'frances_mcdormand', 1.0],
#  ['liam_neeson', 'coworker ', 'edward_furlong', 1.0],
#  ['liam_neeson', 'coworker ', 'maggie_grace', 1.0],
#  ['liam_neeson', 'coworker ', 'caroline_goodall', 1.0],
#  ['liam_neeson', 'coworker ', 'greg_macgillivray', 1.0],
#  ['liam_neeson', 'coworker ', 'maurice_compte', 1.0],
#  ['liam_neeson', 'coworker ', 'oliver_butcher', 1.0],
#  ['liam_neeson', 'coworker ', 'travis_beacham', 1.0],
#  ['liam_neeson', 'coworker ', 'paul_vosloo', 1.0],
#  ['liam_neeson', 'coworker ', 'julia_roberts', 1.0],
#  ['liam_neeson', 'coworker ', 'natasha_richardson', 1.0],
#  ['liam_neeson', 'coworker ', 'lawrence_block', 1.0],
#  ['liam_neeson', 'coworker ', 'catherine_zeta-jones', 1.0],
#  ['liam_neeson', 'coworker ', 'anne_fontaine', 1.0],
#  ['liam_neeson', 'coworker ', 'frank_grillo', 1.0],
#  ['liam_neeson', 'coworker ', 'ed_harris', 1.0],
#  ['liam_neeson', 'coworker ', 'peter_lepeniotis', 1.0],
#  ['liam_neeson', 'coworker ', 'susan_isaacs', 1.0],
#  ['liam_neeson', 'coworker ', 'david_von_ancken', 1.0],
#  ['liam_neeson', 'coworker ', 'bob_kane', 1.0],
#  ['liam_neeson', 'coworker ', 'robert_mark_kamen', 1.0],
#  ['liam_neeson', 'coworker ', 'pierre_morel', 1.0],
#  ['liam_neeson', 'coworker ', 'john_madden', 1.0],
#  ['liam_neeson', 'coworker ', 'justine_bateman', 1.0],
#  ['liam_neeson', 'coworker ', 'larry_drake', 1.0],
#  ['liam_neeson', 'coworker ', 'antonio_banderas', 1.0],
#  ['liam_neeson', 'coworker ', 'bradley_cooper', 1.0],
#  ['liam_neeson', 'coworker ', 'aaron_taylor-johnson', 0.0],
#  ['liam_neeson', 'coworker ', 'charlie_barnett', 0.0],
#  ['liam_neeson', 'coworker ', 'marisa_paredes', 0.0],
#  ['liam_neeson', 'coworker ', 'katya_blumenberg', 0.0],
#  ['liam_neeson', 'coworker ', 'david_e._kelley', 0.0],
#  ['liam_neeson', 'coworker ', 'will_geer', 0.0],
#  ['liam_neeson', 'coworker ', 'lem_dobbs', 0.0],
#  ['liam_neeson', 'coworker ', 'patrick_mccarville', 0.0],
#  ['liam_neeson', 'coworker ', 'mark_tarlov', 0.0],
#  ['liam_neeson', 'coworker ', 'lucky_mckee', 0.0],
#  ['liam_neeson', 'coworker ', 'ariel_dorfman', 0.0],
#  ['liam_neeson', 'coworker ', 'milton_sperling', 0.0],
#  ['liam_neeson', 'coworker ', 'stewart_raffill', 0.0],
#  ['liam_neeson', 'coworker ', 'f._scott_fitzgerald', 0.0],
#  ['liam_neeson', 'coworker ', 'rupert_baderman', 0.0],
#  ['liam_neeson', 'coworker ', 'peter_matthiessen', 0.0],
#  ['liam_neeson', 'coworker ', 'jared_leto', 0.0],
#  ['liam_neeson', 'coworker ', 'jack_black', 0.0],
#  ['liam_neeson', 'coworker ', 'elyne_mitchell', 0.0],
#  ['liam_neeson', 'coworker ', 'emilio_estevez', 0.0],
#  ['liam_neeson', 'coworker ', 'jean-bernard_pouy', 0.0],
#  ['liam_neeson', 'coworker ', 'beau_thorne', 0.0],
#  ['liam_neeson', 'coworker ', 'michael_moriarty', 0.0],
#  ['liam_neeson', 'coworker ', 'bai_ling', 0.0],
#  ['liam_neeson', 'coworker ', 'doug_mckeon', 0.0],
#  ['liam_neeson', 'coworker ', 'rosanna_lavelle', 0.0],
#  ['liam_neeson', 'coworker ', 'anne_parillaud', 0.0],
#  ['liam_neeson', 'coworker ', 'richard_fleischer', 0.0],
#  ['liam_neeson', 'coworker ', 'john_wayne', 0.0],
#  ['liam_neeson', 'coworker ', 'david_warner', 0.0],
#  ['liam_neeson', 'coworker ', 'aaron_taylor-johnson', 0.0],
#  ['liam_neeson', 'coworker ', 'charlie_barnett', 0.0],
#  ['liam_neeson', 'coworker ', 'marisa_paredes', 0.0],
#  ['liam_neeson', 'coworker ', 'katya_blumenberg', 0.0],
#  ['liam_neeson', 'coworker ', 'david_e._kelley', 0.0],
#  ['liam_neeson', 'coworker ', 'will_geer', 0.0],
#  ['liam_neeson', 'coworker ', 'lem_dobbs', 0.0],
#  ['liam_neeson', 'coworker ', 'patrick_mccarville', 0.0],
#  ['liam_neeson', 'coworker ', 'mark_tarlov', 0.0],
#  ['liam_neeson', 'coworker ', 'lucky_mckee', 0.0],
#  ['liam_neeson', 'coworker ', 'ariel_dorfman', 0.0],
#  ['liam_neeson', 'coworker ', 'milton_sperling', 0.0],
#  ['liam_neeson', 'coworker ', 'stewart_raffill', 0.0],
#  ['liam_neeson', 'coworker ', 'f._scott_fitzgerald', 0.0],
#  ['liam_neeson', 'coworker ', 'rupert_baderman', 0.0],
#  ['liam_neeson', 'coworker ', 'peter_matthiessen', 0.0],
#  ['liam_neeson', 'coworker ', 'jared_leto', 0.0],
#  ['liam_neeson', 'coworker ', 'jack_black', 0.0],
#  ['liam_neeson', 'coworker ', 'elyne_mitchell', 0.0],
#  ['liam_neeson', 'coworker ', 'emilio_estevez', 0.0],
#  ['liam_neeson', 'coworker ', 'jean-bernard_pouy', 0.0],
#  ['liam_neeson', 'coworker ', 'beau_thorne', 0.0],
#  ['liam_neeson', 'coworker ', 'michael_moriarty', 0.0],
#  ['liam_neeson', 'coworker ', 'bai_ling', 0.0],
#  ['liam_neeson', 'coworker ', 'doug_mckeon', 0.0],
#  ['liam_neeson', 'coworker ', 'rosanna_lavelle', 0.0],
#  ['liam_neeson', 'coworker ', 'anne_parillaud', 0.0],
#  ['liam_neeson', 'coworker ', 'richard_fleischer', 0.0],
#  ['liam_neeson', 'coworker ', 'john_wayne', 0.0],
#  ['liam_neeson', 'coworker ', 'david_warner', 0.0],
#  ['michael_caine', 'coworker ', 'jane_fonda', 1.0],
#  ['michael_caine', 'coworker ', 'guy_hamilton', 1.0],
#  ['michael_caine', 'coworker ', 'nelson_gidding', 1.0],
#  ['michael_caine', 'coworker ', 'britt_ekland', 1.0],
#  ['michael_caine', 'coworker ', 'john_sturges', 1.0],
#  ['michael_caine', 'coworker ', 'gladys_hill', 1.0],
#  ['michael_caine', 'coworker ', 'patrick_kavanagh', 1.0],
#  ['michael_caine', 'coworker ', 'ivan_passer', 1.0],
#  ['michael_caine', 'coworker ', 'evan_jones', 1.0],
#  ['michael_caine', 'coworker ', 'alvin_sargent', 1.0],
#  ['michael_caine', 'coworker ', 'mark_rydell', 1.0],
#  ['michael_caine', 'coworker ', 'curd_jürgens', 1.0],
#  ['michael_caine', 'coworker ', 'dan_fogelman', 1.0],
#  ['michael_caine', 'coworker ', 'michael_keaton', 1.0],
#  ['michael_caine', 'coworker ', 'christian_bale', 1.0],
#  ['michael_caine', 'coworker ', 'lewis_gilbert', 1.0],
#  ['michael_caine', 'coworker ', 'willy_russell', 1.0],
#  ['michael_caine', 'coworker ', 'kenneth_branagh', 1.0],
#  ['michael_caine', 'coworker ', 'michael_williams', 1.0],
#  ['michael_caine', 'coworker ', 'marc_brandel', 1.0],
#  ['michael_caine', 'coworker ', 'maggie_smith', 1.0],
#  ['michael_caine', 'coworker ', 'frances_barber', 1.0],
#  ['michael_caine', 'coworker ', 'robert_kaufman', 1.0],
#  ['michael_caine', 'coworker ', 'guy_green', 1.0],
#  ['michael_caine', 'coworker ', 'herbert_lom', 1.0],
#  ['michael_caine', 'coworker ', 'brendan_fraser', 1.0],
#  ['michael_caine', 'coworker ', 'phillip_noyce', 1.0],
#  ['michael_caine', 'coworker ', 'shirley_maclaine', 1.0],
#  ['michael_caine', 'coworker ', 'paul_hubschmid', 1.0],
#  ['michael_caine', 'coworker ', 'oskar_homolka', 1.0],
#  ['michael_caine', 'coworker ', 'diahann_carroll', 1.0],
#  ['michael_caine', 'coworker ', 'katya_gilden', 1.0],
#  ['michael_caine', 'coworker ', 'steve_conrad', 1.0],
#  ['michael_caine', 'coworker ', 'rod_hardy', 1.0],
#  ['michael_caine', 'coworker ', 'ben_kingsley', 1.0],
#  ['michael_caine', 'coworker ', 'juan_gabriel_yacuzzi', 1.0],
#  ['michael_caine', 'coworker ', 'ed_begley', 1.0],
#  ['michael_caine', 'coworker ', 'jeffrey_jones', 1.0],
#  ['michael_caine', 'coworker ', 'sol_saks', 1.0],
#  ['michael_caine', 'coworker ', 'ronald_harwood', 1.0],
#  ['michael_caine', 'coworker ', 'james_belushi', 1.0],
#  ['michael_caine', 'coworker ', 'ian_bannen', 1.0],
#  ['michael_caine', 'coworker ', 'dyan_cannon', 1.0],
#  ['michael_caine', 'coworker ', 'liam_neeson', 1.0],
#  ['michael_caine', 'coworker ', 'katie_holmes', 1.0],
#  ['michael_caine', 'coworker ', 'millicent_martin', 1.0],
#  ['michael_caine', 'coworker ', 'jonathan_nolan', 1.0],
#  ['michael_caine', 'coworker ', 'geoffrey_rush', 1.0],
#  ['michael_caine', 'coworker ', 'paul_gallico', 1.0],
#  ['michael_caine', 'coworker ', 'harold_nebenzal', 1.0],
#  ['michael_caine', 'coworker ', 'lionel_stander', 1.0],
#  ['michael_caine', 'coworker ', 'irwin_allen', 1.0],
#  ['michael_caine', 'coworker ', 'glenne_headly', 1.0],
#  ['michael_caine', 'coworker ', 'neil_simon', 1.0],
#  ['michael_caine', 'coworker ', 'nora_ephron', 1.0],
#  ['michael_caine', 'coworker ', 'peter_collinson', 1.0],
#  ['michael_caine', 'coworker ', 'sean_connery', 1.0],
#  ['michael_caine', 'coworker ', 'alfonso_cuarón', 1.0],
#  ['michael_caine', 'coworker ', 'neil_jordan', 1.0],
#  ['michael_caine', 'coworker ', 'john_phillip_law', 1.0],
#  ['michael_caine', 'coworker ', 'barry_morse', 0.0],
#  ['michael_caine', 'coworker ', 'k_callan', 0.0],
#  ['michael_caine', 'coworker ', 'steve_mackall', 0.0],
#  ['michael_caine', 'coworker ', 'barbara_ann_teer', 0.0],
#  ['michael_caine', 'coworker ', 'mary_tamm', 0.0],
#  ['michael_caine', 'coworker ', 'david_bennent', 0.0],
#  ['michael_caine', 'coworker ', 'juliet_snowden', 0.0],
#  ['michael_caine', 'coworker ', 'evangeline_lilly', 0.0],
#  ['michael_caine', 'coworker ', 'heather_mitchell', 0.0],
#  ['michael_caine', 'coworker ', 'gérard_brach', 0.0],
#  ['michael_caine', 'coworker ', 'flip_wilson', 0.0],
#  ['michael_caine', 'coworker ', 'jamey_sheridan', 0.0],
#  ['michael_caine', 'coworker ', 'tobin_bell', 0.0],
#  ['michael_caine', 'coworker ', 'osha_gray_davidson', 0.0],
#  ['michael_caine', 'coworker ', 'harve_presnell', 0.0],
#  ['michael_caine', 'coworker ', 'dale_dye', 0.0],
#  ['michael_caine', 'coworker ', 'alexandre_rockwell', 0.0],
#  ['michael_caine', 'coworker ', 'craig_a._williams', 0.0],
#  ['michael_caine', 'coworker ', 'larry_tucker', 0.0],
#  ['michael_caine', 'coworker ', 'andrew_wyatt', 0.0],
#  ['michael_caine', 'coworker ', 'nigel_kneale', 0.0],
#  ['michael_caine', 'coworker ', 'lewis_carroll', 0.0],
#  ['michael_caine', 'coworker ', 'w.p._lipscomb', 0.0],
#  ['michael_caine', 'coworker ', 'albert_salmi', 0.0],
#  ['michael_caine', 'coworker ', 'guerdon_trueblood', 0.0],
#  ['michael_caine', 'coworker ', 'robert_l._levy', 0.0],
#  ['michael_caine', 'coworker ', 'milan_kundera', 0.0],
#  ['michael_caine', 'coworker ', 'william_templeton', 0.0],
#  ['michael_caine', 'coworker ', 'dan_rush', 0.0],
#  ['michael_caine', 'coworker ', 'nick_mancuso', 0.0],
#  ['michael_caine', 'coworker ', 'tommy_rall', 0.0],
#  ['michael_caine', 'coworker ', 'pat_mccormick', 0.0],
#  ['michael_caine', 'coworker ', 'john_melson', 0.0],
#  ['michael_caine', 'coworker ', 'katya_blumenberg', 0.0],
#  ['michael_caine', 'coworker ', 'michael_brady', 0.0],
#  ['michael_caine', 'coworker ', 'paul_felopulos', 0.0],
#  ['michael_caine', 'coworker ', 'susan_stroman', 0.0],
#  ['michael_caine', 'coworker ', 'lili_taylor', 0.0],
#  ['michael_caine', 'coworker ', 'nick_metropolis', 0.0],
#  ['michael_caine', 'coworker ', 'philip_dunne', 0.0],
#  ['michael_caine', 'coworker ', 'oakley_hall', 0.0],
#  ['michael_caine', 'coworker ', 'moira_kelly', 0.0],
#  ['michael_caine', 'coworker ', 'fionnula_flanagan', 0.0],
#  ['michael_caine', 'coworker ', 'miley_cyrus', 0.0],
#  ['michael_caine', 'coworker ', 'don_macpherson', 0.0],
#  ['michael_caine', 'coworker ', 'steven_collins', 0.0],
#  ['michael_caine', 'coworker ', 'sidney_sheldon', 0.0],
#  ['michael_caine', 'coworker ', 'michael_sayers', 0.0],
#  ['michael_caine', 'coworker ', 'bradley_cooper', 0.0],
#  ['michael_caine', 'coworker ', 'sam_shepard', 0.0],
#  ['michael_caine', 'coworker ', 'james_stewart', 0.0],
#  ['michael_caine', 'coworker ', 'andrew_wilson', 0.0],
#  ['michael_caine', 'coworker ', 'michelle_williams', 0.0],
#  ['michael_caine', 'coworker ', 'ian_fleming', 0.0],
#  ['michael_caine', 'coworker ', 'miranda_richardson', 0.0],
#  ['michael_caine', 'coworker ', 'amy_heckerling', 0.0],
#  ['michael_caine', 'coworker ', 'bruce_willis', 0.0],
#  ['michael_caine', 'coworker ', 'david_greene', 0.0],
#  ['michael_caine', 'coworker ', 'edward_fox', 0.0],
#  ['michael_caine', 'coworker ', 'louise_lasser', 0.0],
#  ['michael_caine', 'coworker ', 'bette_davis', 0.0]]

# %%
type(1.1622906e-06)
# Out:
# float

# %%
round(1.0430813000000002e-06,5)
# Out:
# 0.0
